# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd "/content/drive/MyDrive/MLDL-Project/Code/Codebase_inUse"
# Out:
# Mounted at /content/drive
# /content/drive/.shortcut-targets-by-id/1qdeOmMzRTTZYag_nMfIYW1ptaZ_OpJwD/MLDL-Project/Code/Codebase_inUse

# %%
from main import *

# %%
# !cp -r "/content/drive/MyDrive/MLDL-Project/Code/Codebase_inUse/data" "/content/"

# %%
# %cd "/content/"
# Out:
# /content

# %% [markdown]
# ## T 4.2: Experiments with Best Model from T3.2

# %%
args_dict = {
    'seed' : 42,
    'dataset' : 'idda',
    'model' : 'deeplabv3_mobilenetv2',
    'num_rounds' : 30,
    'num_epochs' : 1,
    'n_exp' : 1,
    'clients_per_round' : 2,
    'print_times' : False,
    'da' : 'advanced',
    'bs' : 8,
    'nw' : 2,
    'lr' : 0.0001,
    'wd' : 0.0001,  #Best for FL
    'opt' : 'SGD',
    'm' : 0.9,
    'policy' : 'poly',
    'lr_power' : 0.9,
    'test' : True,
    'warmup' : 0,
    'train_display_interval' : 1,
    'valid_interval' : 5,
    'n_final_rounds' : 3,
    'save_best_model' : False,
    'mode' : 'SSL',
    'teacher_strat': 1,
    'T': 5,
    'path_model_SSL': "/content/drive/MyDrive/MLDL-Project/Code/Codebase_inUse/Results/Best_Models/T3/exp_26.pth"
}

# %%
main(args_dict)
# Out:
#
#
#  #############################################
#
#  I'm in the experiment:
#   Namespace(seed=42, dataset='idda', model='deeplabv3_mobilenetv2', num_rounds=30, num_epochs=1, n_exp=1, clients_per_round=2, print_times=False, target_miou=0.0, da='advanced', bs=8, nw=2, lr=0.0001, wd=0.0001, hnm=False, opt='SGD', m=0.9, Adam_p=None, policy='poly', lr_power=0.9, lr_step=15, lr_factor=0.1, test=True, warmup=0, train_display_interval=1, valid_interval=5, n_final_rounds=3, save_best_model=False, mode='SSL', teacher_strat=1, T=5, path_model_SSL='/content/drive/MyDrive/MLDL-Project/Code/Codebase_inUse/Results/Best_Models/T3/exp_26.pth')
# Initializing model...
# Done.
# Generate datasets...
# Done.
#  Round 1/30
#  Client 1/2: T03_CN_A_U1
#  Client 2/2: T02_CN_J_U1
#
#  Results:
# 	 - Round_loss=0.17027144630750024
# 	 - Round_mean_IoU=0.9999999999190063
# 	 - Round_fw_IoU=0.99999999999943
# 	 - Round_pix_acc=0.9999999999190063
#  Round 2/30
#  Client 1/2: T01_CN_J_U2
# ...

# %%
args_dict['clients_per_round'] = 8
args_dict['n_exp'] = 2
main(args_dict)
# Out:
#
#
#  #############################################
#
#  I'm in the experiment:
#   Namespace(seed=42, dataset='idda', model='deeplabv3_mobilenetv2', num_rounds=100, num_epochs=1, n_exp=2, clients_per_round=8, print_times=False, target_miou=0.0, da='advanced', bs=8, nw=2, lr=0.1, wd=0.0001, hnm=False, opt='SGD', m=0.9, Adam_p=None, policy='poly', lr_power=0.9, lr_step=15, lr_factor=0.1, test=True, warmup=0, train_display_interval=1, valid_interval=10, n_final_rounds=5, save_best_model=False, mode='SSL', teacher_strat=1, T=5, path_model_SSL='/content/drive/MyDrive/MLDL-Project/Code/Codebase_inUse/Results/Best_Models/T3/exp_26.pth')
# Initializing model...
# Done.
# Generate datasets...
# Done.
#  Round 1/100
#  Client 1/8: T03_CN_A_U1
#  Client 2/8: T02_CN_J_U1
#  Client 3/8: T02_CN_A_U1
#  Client 4/8: T02_CS_J_U1
#  Client 5/8: T02_CS_A_U2
#  Client 6/8: T03_CN_A_U2
#  Client 7/8: T03_CS_J_U2
#  Client 8/8: T02_CN_A_U2
#
#  Results:
# 	 - Round_loss=0.06884728461569453
# ...

# %%
args_dict['clients_per_round'] = 2
args_dict['n_exp'] = 3
args_dict['teacher_strat'] = 2
main(args_dict)
# Out:
#
#
#  #############################################
#
#  I'm in the experiment:
#   Namespace(seed=42, dataset='idda', model='deeplabv3_mobilenetv2', num_rounds=100, num_epochs=1, n_exp=3, clients_per_round=2, print_times=False, target_miou=0.0, da='advanced', bs=8, nw=2, lr=0.1, wd=0.0001, hnm=False, opt='SGD', m=0.9, Adam_p=None, policy='poly', lr_power=0.9, lr_step=15, lr_factor=0.1, test=True, warmup=0, train_display_interval=1, valid_interval=10, n_final_rounds=5, save_best_model=False, mode='SSL', teacher_strat=2, T=5, path_model_SSL='/content/drive/MyDrive/MLDL-Project/Code/Codebase_inUse/Results/Best_Models/T3/exp_26.pth')
# Initializing model...
# Done.
# Generate datasets...
# Done.
#  Round 1/100
#  Client 1/2: T03_CN_A_U1
#  Client 2/2: T02_CN_J_U1
#
#  Results:
# 	 - Round_loss=0.07081176160543615
# 	 - Round_mean_IoU=0.9999999998952395
# 	 - Round_fw_IoU=0.999999999999474
# 	 - Round_pix_acc=0.9999999998952395
#  Round 2/100
#  Client 1/2: T01_CN_J_U2
# ...

# %%
args_dict['clients_per_round'] = 8
args_dict['n_exp'] = 4
args_dict['teacher_strat'] = 2
main(args_dict)
# Out:
#
#
#  #############################################
#
#  I'm in the experiment:
#   Namespace(seed=42, dataset='idda', model='deeplabv3_mobilenetv2', num_rounds=100, num_epochs=1, n_exp=4, clients_per_round=8, print_times=False, target_miou=0.0, da='advanced', bs=8, nw=2, lr=0.1, wd=0.0001, hnm=False, opt='SGD', m=0.9, Adam_p=None, policy='poly', lr_power=0.9, lr_step=15, lr_factor=0.1, test=True, warmup=0, train_display_interval=1, valid_interval=10, n_final_rounds=5, save_best_model=False, mode='SSL', teacher_strat=2, T=5, path_model_SSL='/content/drive/MyDrive/MLDL-Project/Code/Codebase_inUse/Results/Best_Models/T3/exp_26.pth')
# Initializing model...
# Downloading: "https://github.com/d-li14/mobilenetv2.pytorch/raw/master/pretrained/mobilenetv2_1.0-0c6065bc.pth" to /root/.cache/torch/hub/checkpoints/mobilenetv2_1.0-0c6065bc.pth
# 100%|██████████| 13.5M/13.5M [00:00<00:00, 258MB/s]
# Done.
# Generate datasets...
# Done.
#  Round 1/100
#  Client 1/8: T03_CN_A_U1
# ...

# %%
args_dict['clients_per_round'] = 2
args_dict['n_exp'] = 5
args_dict['teacher_strat'] = 3
args_dict['T'] = 5
main(args_dict)
# Out:
#
#
#  #############################################
#
#  I'm in the experiment:
#   Namespace(seed=42, dataset='idda', model='deeplabv3_mobilenetv2', num_rounds=100, num_epochs=1, n_exp=5, clients_per_round=2, print_times=False, target_miou=0.0, da='advanced', bs=8, nw=2, lr=0.1, wd=0.0001, hnm=False, opt='SGD', m=0.9, Adam_p=None, policy='poly', lr_power=0.9, lr_step=15, lr_factor=0.1, test=True, warmup=0, train_display_interval=1, valid_interval=10, n_final_rounds=5, save_best_model=False, mode='SSL', teacher_strat=3, T=5, path_model_SSL='/content/drive/MyDrive/MLDL-Project/Code/Codebase_inUse/Results/Best_Models/T3/exp_26.pth')
# Initializing model...
# Done.
# Generate datasets...
# Done.
#  Round 1/100
#  Client 1/2: T03_CN_A_U1
#  Client 2/2: T02_CN_J_U1
#
#  Results:
# 	 - Round_loss=0.07081176509628524
# 	 - Round_mean_IoU=0.9999999998952395
# 	 - Round_fw_IoU=0.999999999999474
# 	 - Round_pix_acc=0.9999999998952395
#  Round 2/100
#  Client 1/2: T01_CN_J_U2
# ...

# %%
# !cp -r "/content/drive/MyDrive/MLDL-Project/Code/Codebase_inUse/data" "/content/"

# %%
# %cd "/content/"

# %%
args_dict = {
    'seed' : 42,
    'dataset' : 'idda',
    'model' : 'deeplabv3_mobilenetv2',
    'num_rounds' : 100,
    'num_epochs' : 1,
    'n_exp' : 6,
    'clients_per_round' : 8,
    'print_times' : False,
    'da' : 'advanced',
    'bs' : 8,
    'nw' : 2,
    'lr' : 0.1,
    'wd' : 0.0001,
    'opt' : 'SGD',
    'm' : 0.9,
    'policy' : 'poly',
    'lr_power' : 0.9,
    'test' : True,
    'warmup' : 0,
    'train_display_interval' : 1,
    'valid_interval' : 10,
    'n_final_rounds' : 5,
    'save_best_model' : False,
    'mode' : 'SSL',
    'teacher_strat': 3,
    'T': 5,
    'path_model_SSL': "/content/drive/MyDrive/MLDL-Project/Code/Codebase_inUse/Results/Best_Models/T3/exp_26.pth"
}

main(args_dict)

# %%
args_dict['clients_per_round'] = 2
args_dict['n_exp'] = 7
args_dict['T'] = 15
main(args_dict)

# %%
args_dict['clients_per_round'] = 8
args_dict['n_exp'] = 8
main(args_dict)

# %% [markdown]
# ## T 4.3: Experiments with best model from T3.4

# %%
# %cd "/content/"

# %%
args_dict = {
    'seed' : 42,
    'dataset' : 'idda',
    'model' : 'deeplabv3_mobilenetv2',
    'num_rounds' : 100,
    'num_epochs' : 1,
    'n_exp' : 9,
    'clients_per_round' : 2,
    'print_times' : False,
    'da' : 'advanced',
    'bs' : 8,
    'nw' : 2,
    'lr' : 0.1,
    'wd' : 0.0001,
    'opt' : 'SGD',
    'm' : 0.9,
    'policy' : 'poly',
    'lr_power' : 0.9,
    'test' : True,
    'warmup' : 0,
    'train_display_interval' : 1,
    'valid_interval' : 10,
    'n_final_rounds' : 5,
    'save_best_model' : False,
    'mode' : 'SSL',
    'teacher_strat': 1,
    'T': 5,
    'path_model_SSL': "/content/drive/MyDrive/MLDL-Project/Code/Codebase_inUse/Results/Best_Models/T3/exp_24.pth"
}


main(args_dict)
# Out:
#
#
#  #############################################
#
#  I'm in the experiment:
#   Namespace(seed=42, dataset='idda', model='deeplabv3_mobilenetv2', num_rounds=100, num_epochs=1, n_exp=9, clients_per_round=2, print_times=False, target_miou=0.0, da='advanced', bs=8, nw=2, lr=0.1, wd=0.0001, hnm=False, opt='SGD', m=0.9, Adam_p=None, policy='poly', lr_power=0.9, lr_step=15, lr_factor=0.1, test=True, warmup=0, train_display_interval=1, valid_interval=10, n_final_rounds=5, save_best_model=False, mode='SSL', teacher_strat=1, T=5, path_model_SSL='/content/drive/MyDrive/MLDL-Project/Code/Codebase_inUse/Results/Best_Models/T3/exp_24.pth')
# Initializing model...
# Done.
# Generate datasets...
# Done.
#  Round 1/100
#  Client 1/2: T03_CN_A_U1
#  Client 2/2: T02_CN_J_U1
#
#  Results:
# 	 - Round_loss=0.05279073274694425
# 	 - Round_mean_IoU=0.999999999922028
# 	 - Round_fw_IoU=0.9999999999994738
# 	 - Round_pix_acc=0.999999999922028
#  Round 2/100
#  Client 1/2: T01_CN_J_U2
# ...

# %%
args_dict['clients_per_round'] = 8
args_dict['n_exp'] = 10
main(args_dict)
# Out:
#
#
#  #############################################
#
#  I'm in the experiment:
#   Namespace(seed=42, dataset='idda', model='deeplabv3_mobilenetv2', num_rounds=100, num_epochs=1, n_exp=10, clients_per_round=8, print_times=False, target_miou=0.0, da='advanced', bs=8, nw=2, lr=0.1, wd=0.0001, hnm=False, opt='SGD', m=0.9, Adam_p=None, policy='poly', lr_power=0.9, lr_step=15, lr_factor=0.1, test=True, warmup=0, train_display_interval=1, valid_interval=10, n_final_rounds=5, save_best_model=False, mode='SSL', teacher_strat=1, T=5, path_model_SSL='/content/drive/MyDrive/MLDL-Project/Code/Codebase_inUse/Results/Best_Models/T3/exp_24.pth')
# Initializing model...
# Done.
# Generate datasets...
# Done.
#  Round 1/100
#  Client 1/8: T03_CN_A_U1
#  Client 2/8: T02_CN_J_U1
#  Client 3/8: T02_CN_A_U1
#  Client 4/8: T02_CS_J_U1
#  Client 5/8: T02_CS_A_U2
#  Client 6/8: T03_CN_A_U2
#  Client 7/8: T03_CS_J_U2
#  Client 8/8: T02_CN_A_U2
#
#  Results:
# 	 - Round_loss=0.05323786694712283
# ...

# %%
args_dict['clients_per_round'] = 2
args_dict['n_exp'] = 11
args_dict['teacher_strat'] = 2
main(args_dict)
# Out:
#
#
#  #############################################
#
#  I'm in the experiment:
#   Namespace(seed=42, dataset='idda', model='deeplabv3_mobilenetv2', num_rounds=100, num_epochs=1, n_exp=11, clients_per_round=2, print_times=False, target_miou=0.0, da='advanced', bs=8, nw=2, lr=0.1, wd=0.0001, hnm=False, opt='SGD', m=0.9, Adam_p=None, policy='poly', lr_power=0.9, lr_step=15, lr_factor=0.1, test=True, warmup=0, train_display_interval=1, valid_interval=10, n_final_rounds=5, save_best_model=False, mode='SSL', teacher_strat=2, T=5, path_model_SSL='/content/drive/MyDrive/MLDL-Project/Code/Codebase_inUse/Results/Best_Models/T3/exp_24.pth')
# Initializing model...
# Done.
# Generate datasets...
# Done.
#  Round 1/100
#  Client 1/2: T03_CN_A_U1
#  Client 2/2: T02_CN_J_U1
#
#  Results:
# 	 - Round_loss=0.05279073492003025
# 	 - Round_mean_IoU=0.999999999922028
# 	 - Round_fw_IoU=0.9999999999994738
# 	 - Round_pix_acc=0.999999999922028
#  Round 2/100
#  Client 1/2: T01_CN_J_U2
# ...

# %%
args_dict['clients_per_round'] = 8
args_dict['n_exp'] = 12
main(args_dict)
# Out:
#
#
#  #############################################
#
#  I'm in the experiment:
#   Namespace(seed=42, dataset='idda', model='deeplabv3_mobilenetv2', num_rounds=100, num_epochs=1, n_exp=12, clients_per_round=8, print_times=False, target_miou=0.0, da='advanced', bs=8, nw=2, lr=0.1, wd=0.0001, hnm=False, opt='SGD', m=0.9, Adam_p=None, policy='poly', lr_power=0.9, lr_step=15, lr_factor=0.1, test=True, warmup=0, train_display_interval=1, valid_interval=10, n_final_rounds=5, save_best_model=False, mode='SSL', teacher_strat=2, T=5, path_model_SSL='/content/drive/MyDrive/MLDL-Project/Code/Codebase_inUse/Results/Best_Models/T3/exp_24.pth')
# Initializing model...
# Done.
# Generate datasets...
# Done.
#  Round 1/100
#  Client 1/8: T03_CN_A_U1
#  Client 2/8: T02_CN_J_U1
#  Client 3/8: T02_CN_A_U1
#  Client 4/8: T02_CS_J_U1
#  Client 5/8: T02_CS_A_U2
#  Client 6/8: T03_CN_A_U2
#  Client 7/8: T03_CS_J_U2
#  Client 8/8: T02_CN_A_U2
#
#  Results:
# 	 - Round_loss=0.053237939804812486
# ...

# %%
args_dict['clients_per_round'] = 2
args_dict['n_exp'] = 13
args_dict['teacher_strat'] = 3
args_dict['T'] = 5
main(args_dict)
# Out:
#
#
#  #############################################
#
#  I'm in the experiment:
#   Namespace(seed=42, dataset='idda', model='deeplabv3_mobilenetv2', num_rounds=100, num_epochs=1, n_exp=13, clients_per_round=2, print_times=False, target_miou=0.0, da='advanced', bs=8, nw=2, lr=0.1, wd=0.0001, hnm=False, opt='SGD', m=0.9, Adam_p=None, policy='poly', lr_power=0.9, lr_step=15, lr_factor=0.1, test=True, warmup=0, train_display_interval=1, valid_interval=10, n_final_rounds=5, save_best_model=False, mode='SSL', teacher_strat=3, T=5, path_model_SSL='/content/drive/MyDrive/MLDL-Project/Code/Codebase_inUse/Results/Best_Models/T3/exp_24.pth')
# Initializing model...
# Done.
# Generate datasets...
# Done.
#  Round 1/100
#  Client 1/2: T03_CN_A_U1
#  Client 2/2: T02_CN_J_U1
#
#  Results:
# 	 - Round_loss=0.05279073274694425
# 	 - Round_mean_IoU=0.999999999922028
# 	 - Round_fw_IoU=0.9999999999994738
# 	 - Round_pix_acc=0.999999999922028
#  Round 2/100
#  Client 1/2: T01_CN_J_U2
# ...

# %%
args_dict['clients_per_round'] = 8
args_dict['n_exp'] = 14
main(args_dict)
# Out:
#
#
#  #############################################
#
#  I'm in the experiment:
#   Namespace(seed=42, dataset='idda', model='deeplabv3_mobilenetv2', num_rounds=100, num_epochs=1, n_exp=14, clients_per_round=8, print_times=False, target_miou=0.0, da='advanced', bs=8, nw=2, lr=0.1, wd=0.0001, hnm=False, opt='SGD', m=0.9, Adam_p=None, policy='poly', lr_power=0.9, lr_step=15, lr_factor=0.1, test=True, warmup=0, train_display_interval=1, valid_interval=10, n_final_rounds=5, save_best_model=False, mode='SSL', teacher_strat=3, T=5, path_model_SSL='/content/drive/MyDrive/MLDL-Project/Code/Codebase_inUse/Results/Best_Models/T3/exp_24.pth')
# Initializing model...
# Done.
# Generate datasets...
# Done.
#  Round 1/100
#  Client 1/8: T03_CN_A_U1
#  Client 2/8: T02_CN_J_U1
#  Client 3/8: T02_CN_A_U1
#  Client 4/8: T02_CS_J_U1
#  Client 5/8: T02_CS_A_U2
#  Client 6/8: T03_CN_A_U2
#  Client 7/8: T03_CS_J_U2
#  Client 8/8: T02_CN_A_U2
#
#  Results:
# 	 - Round_loss=0.05323786999810451
# ...

# %%
args_dict['clients_per_round'] = 2
args_dict['n_exp'] = 15
args_dict['T'] = 15
main(args_dict)
# Out:
#
#
#  #############################################
#
#  I'm in the experiment:
#   Namespace(seed=42, dataset='idda', model='deeplabv3_mobilenetv2', num_rounds=100, num_epochs=1, n_exp=15, clients_per_round=2, print_times=False, target_miou=0.0, da='advanced', bs=8, nw=2, lr=0.1, wd=0.0001, hnm=False, opt='SGD', m=0.9, Adam_p=None, policy='poly', lr_power=0.9, lr_step=15, lr_factor=0.1, test=True, warmup=0, train_display_interval=1, valid_interval=10, n_final_rounds=5, save_best_model=False, mode='SSL', teacher_strat=3, T=15, path_model_SSL='/content/drive/MyDrive/MLDL-Project/Code/Codebase_inUse/Results/Best_Models/T3/exp_24.pth')
# Initializing model...
# Done.
# Generate datasets...
# Done.
#  Round 1/100
#  Client 1/2: T03_CN_A_U1
#  Client 2/2: T02_CN_J_U1
#
#  Results:
# 	 - Round_loss=0.052790732436503396
# 	 - Round_mean_IoU=0.999999999922028
# 	 - Round_fw_IoU=0.9999999999994738
# 	 - Round_pix_acc=0.999999999922028
#  Round 2/100
#  Client 1/2: T01_CN_J_U2
# ...

# %%
args_dict['clients_per_round'] = 8
args_dict['n_exp'] = 16
main(args_dict)
# Out:
#
#
#  #############################################
#
#  I'm in the experiment:
#   Namespace(seed=42, dataset='idda', model='deeplabv3_mobilenetv2', num_rounds=100, num_epochs=1, n_exp=16, clients_per_round=8, print_times=False, target_miou=0.0, da='advanced', bs=8, nw=2, lr=0.1, wd=0.0001, hnm=False, opt='SGD', m=0.9, Adam_p=None, policy='poly', lr_power=0.9, lr_step=15, lr_factor=0.1, test=True, warmup=0, train_display_interval=1, valid_interval=10, n_final_rounds=5, save_best_model=False, mode='SSL', teacher_strat=3, T=15, path_model_SSL='/content/drive/MyDrive/MLDL-Project/Code/Codebase_inUse/Results/Best_Models/T3/exp_24.pth')
# Initializing model...
# Done.
# Generate datasets...
# Done.
#  Round 1/100
#  Client 1/8: T03_CN_A_U1
#  Client 2/8: T02_CN_J_U1
#  Client 3/8: T02_CN_A_U1
#  Client 4/8: T02_CS_J_U1
#  Client 5/8: T02_CS_A_U2
#  Client 6/8: T03_CN_A_U2
#  Client 7/8: T03_CS_J_U2
#  Client 8/8: T02_CN_A_U2
#
#  Results:
# 	 - Round_loss=0.05323784221243948
# ...

# %% [markdown]
# # Debug

# %%
args_dict = {
    'seed' : 42,
    'dataset' : 'idda',
    'model' : 'deeplabv3_mobilenetv2',
    'num_rounds' : 30,
    'num_epochs' : 1,
    'n_exp' : 1,
    'clients_per_round' : 2,
    'print_times' : False,
    'da' : 'advanced',
    'bs' : 8,
    'nw' : 2,
    'lr' : 0.0001,
    'wd' : 0.0001,  #Best for FL
    'opt' : 'SGD',
    'm' : 0.9,
    'policy' : 'poly',
    'lr_power' : 0.9,
    'test' : True,
    'warmup' : 0,
    'train_display_interval' : 1,
    'valid_interval' : 5,
    'n_final_rounds' : 3,
    'save_best_model' : False,
    'mode' : 'SSL',
    'teacher_strat': 1,
    'T': 5,
    'path_model_SSL': "/content/drive/MyDrive/MLDL-Project/Code/Codebase_inUse/Results/Best_Models/T3/exp_26.pth"
}

# %%
main(args_dict)
# Out:
#
#
#  #############################################
#
#  I'm in the experiment:
#   Namespace(seed=42, dataset='idda', model='deeplabv3_mobilenetv2', num_rounds=30, num_epochs=1, n_exp=1, clients_per_round=2, print_times=False, target_miou=0.0, da='advanced', bs=8, nw=2, lr=0.0001, wd=0.0001, hnm=False, opt='SGD', m=0.9, Adam_p=None, policy='poly', lr_power=0.9, lr_step=15, lr_factor=0.1, test=True, warmup=0, train_display_interval=1, valid_interval=5, n_final_rounds=3, save_best_model=False, mode='SSL', teacher_strat=1, T=5, path_model_SSL='/content/drive/MyDrive/MLDL-Project/Code/Codebase_inUse/Results/Best_Models/T3/exp_26.pth')
# Initializing model...
# Done.
# Generate datasets...
# Done.
#  Round 1/30
#  Client 1/2: T03_CN_A_U1
#  Client 2/2: T02_CN_J_U1
#
#  Results:
# 	 - Round_loss=0.17027144630750024
# 	 - Round_mean_IoU=0.9999999999190063
# 	 - Round_fw_IoU=0.99999999999943
# 	 - Round_pix_acc=0.9999999999190063
#  Round 2/30
#  Client 1/2: T01_CN_J_U2
# ...

# %%
args_dict = {
    'seed' : 42,
    'dataset' : 'idda',
    'model' : 'deeplabv3_mobilenetv2',
    'num_rounds' : 30,
    'num_epochs' : 1,
    'n_exp' : 1,
    'clients_per_round' : 2,
    'print_times' : False,
    'da' : 'advanced',
    'bs' : 8,
    'nw' : 2,
    'lr' : 0.001,
    'wd' : 0.0001,  #Best for FL
    'opt' : 'SGD',
    'm' : 0.9,
    'policy' : 'poly',
    'lr_power' : 0.9,
    'test' : True,
    'warmup' : 0,
    'train_display_interval' : 1,
    'valid_interval' : 5,
    'n_final_rounds' : 3,
    'save_best_model' : False,
    'mode' : 'SSL',
    'teacher_strat': 1,
    'T': 5,
    'path_model_SSL': "/content/drive/MyDrive/MLDL-Project/Code/Codebase_inUse/Results/Best_Models/T3/exp_26.pth"
}

# %%
main(args_dict)
# Out:
#
#
#  #############################################
#
#  I'm in the experiment:
#   Namespace(seed=42, dataset='idda', model='deeplabv3_mobilenetv2', num_rounds=30, num_epochs=1, n_exp=1, clients_per_round=2, print_times=False, target_miou=0.0, da='advanced', bs=8, nw=2, lr=0.001, wd=0.0001, hnm=False, opt='SGD', m=0.9, Adam_p=None, policy='poly', lr_power=0.9, lr_step=15, lr_factor=0.1, test=True, warmup=0, train_display_interval=1, valid_interval=5, n_final_rounds=3, save_best_model=False, mode='SSL', teacher_strat=1, T=5, path_model_SSL='/content/drive/MyDrive/MLDL-Project/Code/Codebase_inUse/Results/Best_Models/T3/exp_26.pth')
# Initializing model...
# Downloading: "https://github.com/d-li14/mobilenetv2.pytorch/raw/master/pretrained/mobilenetv2_1.0-0c6065bc.pth" to /root/.cache/torch/hub/checkpoints/mobilenetv2_1.0-0c6065bc.pth
# 100%|██████████| 13.5M/13.5M [00:00<00:00, 155MB/s]
# Done.
# Generate datasets...
# Done.
#  Round 1/30
#  Client 1/2: T03_CN_A_U1
# ...

# %%
args_dict = {
    'seed' : 42,
    'dataset' : 'idda',
    'model' : 'deeplabv3_mobilenetv2',
    'num_rounds' : 30,
    'num_epochs' : 1,
    'n_exp' : 1,
    'clients_per_round' : 2,
    'print_times' : False,
    'da' : 'advanced',
    'bs' : 8,
    'nw' : 2,
    'lr' : 0.00001,
    'wd' : 0.0001,  #Best for FL
    'opt' : 'SGD',
    'm' : 0.9,
    'policy' : 'poly',
    'lr_power' : 0.9,
    'test' : True,
    'warmup' : 0,
    'train_display_interval' : 1,
    'valid_interval' : 5,
    'n_final_rounds' : 3,
    'save_best_model' : False,
    'mode' : 'SSL',
    'teacher_strat': 1,
    'T': 5,
    'path_model_SSL': "/content/drive/MyDrive/MLDL-Project/Code/Codebase_inUse/Results/Best_Models/T3/exp_26.pth"
}

# %%
main(args_dict)
# Out:
#
#
#  #############################################
#
#  I'm in the experiment:
#   Namespace(seed=42, dataset='idda', model='deeplabv3_mobilenetv2', num_rounds=30, num_epochs=1, n_exp=1, clients_per_round=2, print_times=False, target_miou=0.0, da='advanced', bs=8, nw=2, lr=1e-05, wd=0.0001, hnm=False, opt='SGD', m=0.9, Adam_p=None, policy='poly', lr_power=0.9, lr_step=15, lr_factor=0.1, test=True, warmup=0, train_display_interval=1, valid_interval=5, n_final_rounds=3, save_best_model=False, mode='SSL', teacher_strat=1, T=5, path_model_SSL='/content/drive/MyDrive/MLDL-Project/Code/Codebase_inUse/Results/Best_Models/T3/exp_26.pth')
# Initializing model...
# Done.
# Generate datasets...
# Done.
#  Round 1/30
#  Client 1/2: T03_CN_A_U1
#  Client 2/2: T02_CN_J_U1
#
#  Results:
# 	 - Round_loss=0.17447280883789062
# 	 - Round_mean_IoU=0.9999999999272966
# 	 - Round_fw_IoU=0.99999999999943
# 	 - Round_pix_acc=0.9999999999272966
#  Round 2/30
#  Client 1/2: T01_CN_J_U2
# ...

# %%
args_dict = {
    'seed' : 42,
    'dataset' : 'idda',
    'model' : 'deeplabv3_mobilenetv2',
    'num_rounds' : 30,
    'num_epochs' : 1,
    'n_exp' : 1,
    'clients_per_round' : 2,
    'print_times' : False,
    'da' : 'advanced',
    'bs' : 8,
    'nw' : 2,
    'lr' : 0.00001,
    'wd' : 0.0001,  #Best for FL
    'opt' : 'SGD',
    'm' : 0.9,
    'policy' : 'poly',
    'lr_power' : 0.9,
    'test' : True,
    'warmup' : 0,
    'train_display_interval' : 1,
    'valid_interval' : 5,
    'n_final_rounds' : 3,
    'save_best_model' : False,
    'mode' : 'SSL',
    'teacher_strat': 1,
    'T': 5,
    'path_model_SSL': "/content/drive/MyDrive/MLDL-Project/Code/Codebase_inUse/Results/Best_Models/T3/exp_24.pth"
}

# %%
main(args_dict)
# Out:
#
#
#  #############################################
#
#  I'm in the experiment:
#   Namespace(seed=42, dataset='idda', model='deeplabv3_mobilenetv2', num_rounds=30, num_epochs=1, n_exp=1, clients_per_round=2, print_times=False, target_miou=0.0, da='advanced', bs=8, nw=2, lr=1e-05, wd=0.0001, hnm=False, opt='SGD', m=0.9, Adam_p=None, policy='poly', lr_power=0.9, lr_step=15, lr_factor=0.1, test=True, warmup=0, train_display_interval=1, valid_interval=5, n_final_rounds=3, save_best_model=False, mode='SSL', teacher_strat=1, T=5, path_model_SSL='/content/drive/MyDrive/MLDL-Project/Code/Codebase_inUse/Results/Best_Models/T3/exp_24.pth')
# Initializing model...
# Downloading: "https://github.com/d-li14/mobilenetv2.pytorch/raw/master/pretrained/mobilenetv2_1.0-0c6065bc.pth" to /root/.cache/torch/hub/checkpoints/mobilenetv2_1.0-0c6065bc.pth
# 100%|██████████| 13.5M/13.5M [00:00<00:00, 108MB/s]
# Done.
# Generate datasets...
# Done.
#  Round 1/30
#  Client 1/2: T03_CN_A_U1
# ...
