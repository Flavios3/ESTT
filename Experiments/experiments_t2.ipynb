# %% [markdown]
# # Setting iniziale

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd "/content/drive/MyDrive/MLDL-Project/Code/Codebase_inUse"
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/MLDL-Project/Code/Codebase_inUse

# %%
from main import *

# %% [markdown]
# - Part I: table
# - Part II: to the end
#
# for part I:
# - 2, 3
# - 2, 6
# - 4, 1
# - 4, 3
# - 4, 6
# - 8, 1
# - 8, 3
# with
# - num rounds = 30
# - valid interval = 5
# - final rounds = 3
#
# for part II:
# - 2, 1
# - 8, 6
# - max time=8h=28800
# - validation itnerval = 10
# - time for round = 240+7 = 247
# - num_rounds = 110 (rounded from 116)

# %% [markdown]
# # Part I - shorter experiment
#
# We test all the combinations of
#
# - local epochs: [1,3,6]
# - clients per round: [2,4,8]
#
# for a fixed num_rounds = 30

# %%
args_dict = {
    'seed' : 42,
    'dataset' : 'idda',
    'model' : 'deeplabv3_mobilenetv2',
    'num_rounds' : 30,
    'num_epochs' : 1,
    'n_exp' : 1,
    'clients_per_round' : 2,
    'print_times' : False,
    'da' : 'advanced',
    'bs' : 8,
    'nw' : 2,
    'lr' : 0.1,
    'wd' : 0.0001,
    'opt' : 'SGD',
    'm' : 0.9,
    'policy' : 'poly',
    'lr_power' : 0.9,
    'test' : True,
    'warmup' : 0,
    'train_display_interval' : 1,
    'valid_interval' : 5,
    'n_final_rounds' : 3,
    'save_best_model' : False,
    'mode' : 'SL',
}

# %%
# Exp. 1: (clients_per_round, n_epochs) = (2,1)

main(args_dict)
# Out:
#
#
#  #############################################
#
#  I'm in the experiment:
#   Namespace(seed=42, dataset='idda', model='deeplabv3_mobilenetv2', num_rounds=30, num_epochs=1, n_exp=1, clients_per_round=2, print_times=False, da='advanced', bs=8, nw=2, lr=0.1, wd=0.0001, hnm=False, opt='SGD', m=0.9, Adam_p=None, policy='poly', lr_power=0.9, lr_step=15, lr_factor=0.1, test=True, warmup=0, train_display_interval=1, valid_interval=5, n_final_rounds=3, save_best_model=False, mode='SL', teacher_strat=1, T=5, pretrained_model=None)
# Initializing model...
# Downloading: "https://github.com/d-li14/mobilenetv2.pytorch/raw/master/pretrained/mobilenetv2_1.0-0c6065bc.pth" to /root/.cache/torch/hub/checkpoints/mobilenetv2_1.0-0c6065bc.pth
# 100%|██████████| 13.5M/13.5M [00:00<00:00, 257MB/s]
# Done.
# Generate datasets...
# Done.
#  Round 1/30
#  Client 1/2: T03_CN_A_U1
#  Client 2/2: T02_CN_J_U1
#
#  Results:
# 	 - Round_loss=1.9759001731872559
# 	 - Round_mean_IoU=0.09357554863213986
# ...

# %%
# Exp. 2: (clients_per_round, n_epochs) = (2,3)

args_dict['num_epochs'] = 3
args_dict['n_exp'] = 2

main(args_dict)
# Out:
#
#
#  #############################################
#
#  I'm in the experiment:
#   Namespace(seed=42, dataset='idda', model='deeplabv3_mobilenetv2', num_rounds=30, num_epochs=3, n_exp=1, clients_per_round=2, print_times=False, da='advanced', bs=8, nw=2, lr=0.1, wd=0.0001, hnm=False, opt='SGD', m=0.9, Adam_p=None, policy='poly', lr_power=0.9, lr_step=15, lr_factor=0.1, test=True, warmup=0, train_display_interval=1, valid_interval=5, n_final_rounds=3, save_best_model=False, mode='SL', teacher_strat=1, T=5, pretrained_model=None)
# Initializing model...
# Done.
# Generate datasets...
# Done.
#  Round 1/30
#  Client 1/2: T03_CN_A_U1
#  Client 2/2: T02_CN_J_U1
#
#  Results:
# 	 - Round_loss=0.5728511611620586
# 	 - Round_mean_IoU=0.17926098013324115
# 	 - Round_fw_IoU=0.5514727835355495
# 	 - Round_pix_acc=0.22015760824604855
#  Round 2/30
#  Client 1/2: T01_CN_J_U2
#  Client 2/2: T02_CS_J_U1
#
#  Results:
# 	 - Round_loss=0.5319280376036962
# 	 - Round_mean_IoU=0.24837753456721262
# ...

# %%
# Exp. 3: (clients_per_round, n_epochs) = (2,6)

args_dict['num_epochs'] = 6
args_dict['n_exp'] = 3

main(args_dict)
# Out:
#
#
#  #############################################
#
#  I'm in the experiment:
#   Namespace(seed=42, dataset='idda', model='deeplabv3_mobilenetv2', num_rounds=30, num_epochs=6, n_exp=2, clients_per_round=2, print_times=False, da='advanced', bs=8, nw=2, lr=0.1, wd=0.0001, hnm=False, opt='SGD', m=0.9, Adam_p=None, policy='poly', lr_power=0.9, lr_step=15, lr_factor=0.1, test=True, warmup=0, train_display_interval=1, valid_interval=5, n_final_rounds=3, save_best_model=False, mode='SL', teacher_strat=1, T=5, pretrained_model=None)
# Initializing model...
# Done.
# Generate datasets...
# Done.
#  Round 1/30
#  Client 1/2: T03_CN_A_U1
#  Client 2/2: T02_CN_J_U1
#
#  Results:
# 	 - Round_loss=0.42577186723550164
# 	 - Round_mean_IoU=0.2324124925604357
# 	 - Round_fw_IoU=0.6575277624567093
# 	 - Round_pix_acc=0.27653847000013826
#  Round 2/30
#  Client 1/2: T01_CN_J_U2
#  Client 2/2: T02_CS_J_U1
#
#  Results:
# 	 - Round_loss=0.41438979407151544
# 	 - Round_mean_IoU=0.2756285334942563
# ...

# %%
# Exp. 4: (clients_per_round, n_epochs) = (4,1)

args_dict['num_epochs'] = 1
args_dict['clients_per_round'] = 4
args_dict['n_exp'] = 4

main(args_dict)
# Out:
#
#
#  #############################################
#
#  I'm in the experiment:
#   Namespace(seed=42, dataset='idda', model='deeplabv3_mobilenetv2', num_rounds=30, num_epochs=1, n_exp=3, clients_per_round=4, print_times=False, da='advanced', bs=8, nw=2, lr=0.1, wd=0.0001, hnm=False, opt='SGD', m=0.9, Adam_p=None, policy='poly', lr_power=0.9, lr_step=15, lr_factor=0.1, test=True, warmup=0, train_display_interval=1, valid_interval=5, n_final_rounds=3, save_best_model=False, mode='SL', teacher_strat=1, T=5, pretrained_model=None)
# Initializing model...
# Done.
# Generate datasets...
# Done.
#  Round 1/30
#  Client 1/4: T03_CN_A_U1
#  Client 2/4: T02_CN_J_U1
#  Client 3/4: T02_CN_A_U1
#  Client 4/4: T02_CS_J_U1
#
#  Results:
# 	 - Round_loss=2.0078749557336173
# 	 - Round_mean_IoU=0.09944466719347703
# 	 - Round_fw_IoU=0.33926861865448316
# 	 - Round_pix_acc=0.15417777477634184
#  Round 2/30
#  Client 1/4: T01_CN_J_U2
#  Client 2/4: T02_CS_J_U1
#  Client 3/4: T02_CN_A_U2
# ...

# %%
# Exp. 5: (clients_per_round, n_epochs) = (4,3)

args_dict['num_epochs'] = 3
args_dict['n_exp'] = 5

main(args_dict)
# Out:
# /content/drive/.shortcut-targets-by-id/1qdeOmMzRTTZYag_nMfIYW1ptaZ_OpJwD/MLDL-Project/Code/Codebase_inUse
#
#
#  #############################################
#
#  I'm in the experiment:
#   Namespace(seed=42, dataset='idda', model='deeplabv3_mobilenetv2', num_rounds=30, num_epochs=3, n_exp=4, clients_per_round=4, print_times=False, da='advanced', bs=8, nw=2, lr=0.1, wd=0.0001, hnm=False, opt='SGD', m=0.9, Adam_p=None, policy='poly', lr_power=0.9, lr_step=15, lr_factor=0.1, test=True, warmup=0, train_display_interval=1, valid_interval=5, n_final_rounds=3, save_best_model=False, mode='SL', teacher_strat=1, T=5, pretrained_model=None)
# Initializing model...
# Done.
# Generate datasets...
# Done.
#  Round 1/30
#  Client 1/4: T03_CN_A_U1
#  Client 2/4: T02_CN_J_U1
#  Client 3/4: T02_CN_A_U1
#  Client 4/4: T02_CS_J_U1
#
#  Results:
# 	 - Round_loss=0.5968215887745222
# 	 - Round_mean_IoU=0.1835795509319719
# 	 - Round_fw_IoU=0.5389619119735474
# 	 - Round_pix_acc=0.23008604842440425
# ...

# %%
# Exp. 6: (clients_per_round, n_epochs) = (4,6)

args_dict['num_epochs'] = 6
args_dict['n_exp'] = 6

main(args_dict)
# Out:
#
#
#  #############################################
#
#  I'm in the experiment:
#   Namespace(seed=42, dataset='idda', model='deeplabv3_mobilenetv2', num_rounds=30, num_epochs=6, n_exp=6, clients_per_round=2, print_times=False, da='advanced', bs=8, nw=2, lr=0.1, wd=0.0001, hnm=False, opt='SGD', m=0.9, Adam_p=None, policy='poly', lr_power=0.9, lr_step=15, lr_factor=0.1, test=True, warmup=0, train_display_interval=1, valid_interval=5, n_final_rounds=3, save_best_model=False, mode='SL', teacher_strat=1, T=5, pretrained_model=None)
# Initializing model...
# Done.
# Generate datasets...
# Done.
#  Round 1/30
#  Client 1/2: T03_CN_A_U1
#  Client 2/2: T02_CN_J_U1
#
#  Results:
# 	 - Round_loss=0.42512470980485273
# 	 - Round_mean_IoU=0.23256950230739915
# 	 - Round_fw_IoU=0.6578350343313215
# 	 - Round_pix_acc=0.2767569210959388
#  Round 2/30
#  Client 1/2: T01_CN_J_U2
#  Client 2/2: T02_CS_J_U1
#
#  Results:
# 	 - Round_loss=0.4130081236362457
# 	 - Round_mean_IoU=0.2759566487900873
# ...

# %%
# Exp. 7: (clients_per_round, n_epochs) = (8,1)

args_dict['num_epochs'] = 1
args_dict['clients_per_round'] = 8
args_dict['n_exp'] = 7

main(args_dict)
# Out:
#
#
#  #############################################
#
#  I'm in the experiment:
#   Namespace(seed=42, dataset='idda', model='deeplabv3_mobilenetv2', num_rounds=30, num_epochs=1, n_exp=7, clients_per_round=8, print_times=False, da='advanced', bs=8, nw=2, lr=0.1, wd=0.0001, hnm=False, opt='SGD', m=0.9, Adam_p=None, policy='poly', lr_power=0.9, lr_step=15, lr_factor=0.1, test=True, warmup=0, train_display_interval=1, valid_interval=5, n_final_rounds=3, save_best_model=False, mode='SL', teacher_strat=1, T=5, pretrained_model=None)
# Initializing model...
# Done.
# Generate datasets...
# Done.
#  Round 1/30
#  Client 1/8: T03_CN_A_U1
#  Client 2/8: T02_CN_J_U1
#  Client 3/8: T02_CN_A_U1
#  Client 4/8: T02_CS_J_U1
#  Client 5/8: T02_CS_A_U2
#  Client 6/8: T03_CN_A_U2
#  Client 7/8: T03_CS_J_U2
#  Client 8/8: T02_CN_A_U2
#
#  Results:
# 	 - Round_loss=1.9897435506184897
# 	 - Round_mean_IoU=0.09852784053083097
# 	 - Round_fw_IoU=0.3450309639295914
# 	 - Round_pix_acc=0.14816770223083606
# ...

# %%
# Exp. 8: (clients_per_round, n_epochs) = (8,3)

args_dict['num_epochs'] = 3
args_dict['n_exp'] = 8

main(args_dict)
# Out:
#
#
#  #############################################
#
#  I'm in the experiment:
#   Namespace(seed=42, dataset='idda', model='deeplabv3_mobilenetv2', num_rounds=30, num_epochs=3, n_exp=8, clients_per_round=8, print_times=False, da='advanced', bs=8, nw=2, lr=0.1, wd=0.0001, hnm=False, opt='SGD', m=0.9, Adam_p=None, policy='poly', lr_power=0.9, lr_step=15, lr_factor=0.1, test=True, warmup=0, train_display_interval=1, valid_interval=5, n_final_rounds=3, save_best_model=False, mode='SL', teacher_strat=1, T=5, pretrained_model=None)
# Initializing model...
# Done.
# Generate datasets...
# Done.
#  Round 1/30
#  Client 1/8: T03_CN_A_U1
#  Client 2/8: T02_CN_J_U1
#  Client 3/8: T02_CN_A_U1
#  Client 4/8: T02_CS_J_U1
#  Client 5/8: T02_CS_A_U2
#  Client 6/8: T03_CN_A_U2
#  Client 7/8: T03_CS_J_U2
#  Client 8/8: T02_CN_A_U2
#
#  Results:
# 	 - Round_loss=0.587328527122736
# 	 - Round_mean_IoU=0.18362184403142534
# 	 - Round_fw_IoU=0.5520866185655867
# 	 - Round_pix_acc=0.22722025403587226
# ...

# %%
# Exp. 9: (clients_per_round, n_epochs) = (8,6)

args_dict['num_epochs'] = 6
args_dict['clients_per_round'] = 8
args_dict['n_exp'] = 9

main(args_dict)
# Out:
#
#
#  #############################################
#
#  I'm in the experiment:
#   Namespace(seed=42, dataset='idda', model='deeplabv3_mobilenetv2', num_rounds=30, num_epochs=6, n_exp=9, clients_per_round=8, print_times=False, da='advanced', bs=8, nw=2, lr=0.1, wd=0.0001, hnm=False, opt='SGD', m=0.9, Adam_p=None, policy='poly', lr_power=0.9, lr_step=15, lr_factor=0.1, test=True, warmup=0, train_display_interval=1, valid_interval=5, n_final_rounds=3, save_best_model=False, mode='SL', teacher_strat=1, T=5, pretrained_model=None)
# Initializing model...
# Done.
# Generate datasets...
# Done.
#  Round 1/30
#  Client 1/8: T03_CN_A_U1
#  Client 2/8: T02_CN_J_U1
#  Client 3/8: T02_CN_A_U1
#  Client 4/8: T02_CS_J_U1
#  Client 5/8: T02_CS_A_U2
#  Client 6/8: T03_CN_A_U2
#  Client 7/8: T03_CS_J_U2
#  Client 8/8: T02_CN_A_U2
#
#  Results:
# 	 - Round_loss=0.4288916575411956
# 	 - Round_mean_IoU=0.23189989063137853
# 	 - Round_fw_IoU=0.6528221915537816
# 	 - Round_pix_acc=0.2783632898434083
# ...

# %% [markdown]
# # Part II - long experiment
#
# We train to the end the combinations
#
# - (local_epochs, clients_per_round) = (3, 2)
# - (local_epochs, clients_per_round) = (3, 8)
#
# for num_rounds = 110 (i.e., in both scenarios we maximize the local computation so to best leverage each commuicaiton)

# %%
args_dict = {
    'seed' : 42,
    'dataset' : 'idda',
    'model' : 'deeplabv3_mobilenetv2',
    'num_rounds' : 110,
    'num_epochs' : 3,
    'n_exp' : 10,
    'clients_per_round' : 2,
    'print_times' : False,
    'da' : 'advanced',
    'bs' : 8,
    'nw' : 2,
    'lr' : 0.1,
    'wd' : 0.0001,
    'opt' : 'SGD',
    'm' : 0.9,
    'policy' : 'poly',
    'lr_power' : 0.9,
    'test' : True,
    'warmup' : 0,
    'train_display_interval' : 1,
    'valid_interval' : 5,
    'n_final_rounds' : 5,
    'save_best_model' : True,
    'mode' : 'SL',
}

main(args_dict)

#done in 1h30m
# Out:
#
#
#  #############################################
#
#  I'm in the experiment:
#   Namespace(seed=42, dataset='idda', model='deeplabv3_mobilenetv2', num_rounds=110, num_epochs=3, n_exp=10, clients_per_round=2, print_times=False, target_miou=0.0, da='advanced', bs=8, nw=2, lr=0.1, wd=0.0001, hnm=False, opt='SGD', m=0.9, Adam_p=None, policy='poly', lr_power=0.9, lr_step=15, lr_factor=0.1, test=True, warmup=0, train_display_interval=1, valid_interval=5, n_final_rounds=5, save_best_model=True, mode='SL', teacher_strat=1, T=5, pretrained_model=None)
# Initializing model...
# Downloading: "https://github.com/d-li14/mobilenetv2.pytorch/raw/master/pretrained/mobilenetv2_1.0-0c6065bc.pth" to /root/.cache/torch/hub/checkpoints/mobilenetv2_1.0-0c6065bc.pth
# 100%|██████████| 13.5M/13.5M [00:00<00:00, 178MB/s]
# Done.
# Generate datasets...
# Done.
#  Round 1/110
#  Client 1/2: T03_CN_A_U1
#  Client 2/2: T02_CN_J_U1
#
#  Results:
# 	 - Round_loss=0.5740171869595846
# ...

# %%
args_dict = {
    'seed' : 42,
    'dataset' : 'idda',
    'model' : 'deeplabv3_mobilenetv2',
    'num_rounds' : 110,
    'num_epochs' : 3,
    'n_exp' : 11,
    'clients_per_round' : 8,
    'print_times' : False,
    'da' : 'advanced',
    'bs' : 8,
    'nw' : 2,
    'lr' : 0.1,
    'wd' : 0.0001,
    'opt' : 'SGD',
    'm' : 0.9,
    'policy' : 'poly',
    'lr_power' : 0.9,
    'test' : True,
    'warmup' : 0,
    'train_display_interval' : 1,
    'valid_interval' : 5,
    'n_final_rounds' : 5,
    'save_best_model' : True,
    'mode' : 'SL',
}

main(args_dict)
# Out:
#
#
#  #############################################
#
#  I'm in the experiment:
#   Namespace(seed=42, dataset='idda', model='deeplabv3_mobilenetv2', num_rounds=110, num_epochs=3, n_exp=11, clients_per_round=8, print_times=False, target_miou=0.0, da='advanced', bs=8, nw=2, lr=0.1, wd=0.0001, hnm=False, opt='SGD', m=0.9, Adam_p=None, policy='poly', lr_power=0.9, lr_step=15, lr_factor=0.1, test=True, warmup=0, train_display_interval=1, valid_interval=5, n_final_rounds=5, save_best_model=True, mode='SL', teacher_strat=1, T=5, pretrained_model=None)
# Initializing model...
# Downloading: "https://github.com/d-li14/mobilenetv2.pytorch/raw/master/pretrained/mobilenetv2_1.0-0c6065bc.pth" to /root/.cache/torch/hub/checkpoints/mobilenetv2_1.0-0c6065bc.pth
# 100%|██████████| 13.5M/13.5M [00:00<00:00, 294MB/s]
# Done.
# Generate datasets...
# Done.
#  Round 1/110
#  Client 1/8: T03_CN_A_U1
#  Client 2/8: T02_CN_J_U1
#  Client 3/8: T02_CN_A_U1
#  Client 4/8: T02_CS_J_U1
# ...

# %% [markdown]
# # Part III - fixed accuracy
#
# To analyze the tradeoff between clients_per_round and num_rounds, we fix a target mIoU (0.38?) and count how many "comunications" happen in each configuration unitl its reached;
#
# Obviously, #comunications=#rounds x #clients_pre_rounds

# %%
args_dict = {
    'seed' : 42,
    'dataset' : 'idda',
    'model' : 'deeplabv3_mobilenetv2',
    'num_rounds' : 110,
    'num_epochs' : 3,
    'n_exp' : 12,
    'clients_per_round' : 2,
    'print_times' : False,
    'da' : 'advanced',
    'bs' : 8,
    'nw' : 2,
    'lr' : 0.1,
    'wd' : 0.0001,
    'opt' : 'SGD',
    'm' : 0.9,
    'policy' : 'poly',
    'lr_power' : 0.9,
    'test' : True,
    'warmup' : 0,
    'train_display_interval' : 1,
    'valid_interval' : 1,
    'n_final_rounds' : 1,
    'save_best_model' : False,
    'mode' : 'SL',
    'target_miou' : 0.38
}

main(args_dict)
# Out:
#
#
#  #############################################
#
#  I'm in the experiment:
#   Namespace(seed=42, dataset='idda', model='deeplabv3_mobilenetv2', num_rounds=110, num_epochs=3, n_exp=12, clients_per_round=2, print_times=False, target_miou=0.38, da='advanced', bs=8, nw=2, lr=0.1, wd=0.0001, hnm=False, opt='SGD', m=0.9, Adam_p=None, policy='poly', lr_power=0.9, lr_step=15, lr_factor=0.1, test=True, warmup=0, train_display_interval=1, valid_interval=1, n_final_rounds=1, save_best_model=False, mode='SL', teacher_strat=1, T=5, pretrained_model=None)
# Initializing model...
# Downloading: "https://github.com/d-li14/mobilenetv2.pytorch/raw/master/pretrained/mobilenetv2_1.0-0c6065bc.pth" to /root/.cache/torch/hub/checkpoints/mobilenetv2_1.0-0c6065bc.pth
# 100%|██████████| 13.5M/13.5M [00:00<00:00, 132MB/s]
# Done.
# Generate datasets...
# Done.
#  Round 1/110
#  Client 1/2: T03_CN_A_U1
#  Client 2/2: T02_CN_J_U1
#
#  Results:
# 	 - Round_loss=0.5723987519741058
# ...

# %%
args_dict = {
    'seed' : 42,
    'dataset' : 'idda',
    'model' : 'deeplabv3_mobilenetv2',
    'num_rounds' : 110,
    'num_epochs' : 3,
    'n_exp' : 13,
    'clients_per_round' : 4,
    'print_times' : False,
    'da' : 'advanced',
    'bs' : 8,
    'nw' : 2,
    'lr' : 0.1,
    'wd' : 0.0001,
    'opt' : 'SGD',
    'm' : 0.9,
    'policy' : 'poly',
    'lr_power' : 0.9,
    'test' : True,
    'warmup' : 0,
    'train_display_interval' : 1,
    'valid_interval' : 1,
    'n_final_rounds' : 1,
    'save_best_model' : False,
    'mode' : 'SL',
    'target_miou' : 0.38
}

main(args_dict)
# Out:
#
#
#  #############################################
#
#  I'm in the experiment:
#   Namespace(seed=42, dataset='idda', model='deeplabv3_mobilenetv2', num_rounds=110, num_epochs=3, n_exp=13, clients_per_round=4, print_times=False, target_miou=0.38, da='advanced', bs=8, nw=2, lr=0.1, wd=0.0001, hnm=False, opt='SGD', m=0.9, Adam_p=None, policy='poly', lr_power=0.9, lr_step=15, lr_factor=0.1, test=True, warmup=0, train_display_interval=1, valid_interval=1, n_final_rounds=1, save_best_model=False, mode='SL', teacher_strat=1, T=5, pretrained_model=None)
# Initializing model...
# Downloading: "https://github.com/d-li14/mobilenetv2.pytorch/raw/master/pretrained/mobilenetv2_1.0-0c6065bc.pth" to /root/.cache/torch/hub/checkpoints/mobilenetv2_1.0-0c6065bc.pth
# 100%|██████████| 13.5M/13.5M [00:00<00:00, 128MB/s]
# Done.
# Generate datasets...
# Done.
#  Round 1/110
#  Client 1/4: T03_CN_A_U1
#  Client 2/4: T02_CN_J_U1
#  Client 3/4: T02_CN_A_U1
#  Client 4/4: T02_CS_J_U1
#
#  Results:
# ...

# %%
args_dict = {
    'seed' : 42,
    'dataset' : 'idda',
    'model' : 'deeplabv3_mobilenetv2',
    'num_rounds' : 110,
    'num_epochs' : 3,
    'n_exp' : 14,
    'clients_per_round' : 8,
    'print_times' : False,
    'da' : 'advanced',
    'bs' : 8,
    'nw' : 2,
    'lr' : 0.1,
    'wd' : 0.0001,
    'opt' : 'SGD',
    'm' : 0.9,
    'policy' : 'poly',
    'lr_power' : 0.9,
    'test' : True,
    'warmup' : 0,
    'train_display_interval' : 1,
    'valid_interval' : 1,
    'n_final_rounds' : 1,
    'save_best_model' : False,
    'mode' : 'SL',
    'target_miou' : 0.38
}

main(args_dict)
# Out:
#
#
#  #############################################
#
#  I'm in the experiment:
#   Namespace(seed=42, dataset='idda', model='deeplabv3_mobilenetv2', num_rounds=110, num_epochs=3, n_exp=14, clients_per_round=8, print_times=False, target_miou=0.38, da='advanced', bs=8, nw=2, lr=0.1, wd=0.0001, hnm=False, opt='SGD', m=0.9, Adam_p=None, policy='poly', lr_power=0.9, lr_step=15, lr_factor=0.1, test=True, warmup=0, train_display_interval=1, valid_interval=1, n_final_rounds=1, save_best_model=False, mode='SL', teacher_strat=1, T=5, pretrained_model=None)
# Initializing model...
# Downloading: "https://github.com/d-li14/mobilenetv2.pytorch/raw/master/pretrained/mobilenetv2_1.0-0c6065bc.pth" to /root/.cache/torch/hub/checkpoints/mobilenetv2_1.0-0c6065bc.pth
# 100%|██████████| 13.5M/13.5M [00:00<00:00, 233MB/s]
# Done.
# Generate datasets...
# Done.
#  Round 1/110
#  Client 1/8: T03_CN_A_U1
#  Client 2/8: T02_CN_J_U1
#  Client 3/8: T02_CN_A_U1
#  Client 4/8: T02_CS_J_U1
# ...

# %%
# BEFORE EXIT PRINT THE TEST RESULTS

# %% [markdown]
# # Part IIB - long experiment (made comparable)
#
# We train to the end the combinations
#
# - (local_epochs, clients_per_round) = (3, 2)
# - (local_epochs, clients_per_round) = (3, 8)
#
# for num_rounds = 100 (i.e., in both scenarios we maximize the local computation so to best leverage each commuicaiton)

# %%
args_dict = {
    'seed' : 42,
    'dataset' : 'idda',
    'model' : 'deeplabv3_mobilenetv2',
    'num_rounds' : 100,
    'num_epochs' : 3,
    'n_exp' : 15,
    'clients_per_round' : 2,
    'print_times' : False,
    'da' : 'advanced',
    'bs' : 8,
    'nw' : 2,
    'lr' : 0.1,
    'wd' : 0.0001,
    'opt' : 'SGD',
    'm' : 0.9,
    'policy' : 'poly',
    'lr_power' : 0.9,
    'test' : True,
    'warmup' : 0,
    'train_display_interval' : 1,
    'valid_interval' : 5,
    'n_final_rounds' : 5,
    'save_best_model' : True,
    'mode' : 'SL',
}

main(args_dict)

#done in 1h30m
# Out:
#
#
#  #############################################
#
#  I'm in the experiment:
#   Namespace(seed=42, dataset='idda', model='deeplabv3_mobilenetv2', num_rounds=100, num_epochs=3, n_exp=15, clients_per_round=2, print_times=False, target_miou=0.0, da='advanced', bs=8, nw=2, lr=0.1, wd=0.0001, hnm=False, opt='SGD', m=0.9, Adam_p=None, policy='poly', lr_power=0.9, lr_step=15, lr_factor=0.1, test=True, warmup=0, train_display_interval=1, valid_interval=5, n_final_rounds=5, save_best_model=True, mode='SL', teacher_strat=1, T=5, path_model_SSL=None)
# Initializing model...
# Downloading: "https://github.com/d-li14/mobilenetv2.pytorch/raw/master/pretrained/mobilenetv2_1.0-0c6065bc.pth" to /root/.cache/torch/hub/checkpoints/mobilenetv2_1.0-0c6065bc.pth
# 100%|██████████| 13.5M/13.5M [00:00<00:00, 242MB/s]
# Done.
# Generate datasets...
# Done.
#  Round 1/100
#  Client 1/2: T03_CN_A_U1
#  Client 2/2: T02_CN_J_U1
#
#  Results:
# 	 - Round_loss=0.5717512965202332
# ...

# %%
args_dict = {
    'seed' : 42,
    'dataset' : 'idda',
    'model' : 'deeplabv3_mobilenetv2',
    'num_rounds' : 100,
    'num_epochs' : 3,
    'n_exp' : 16,
    'clients_per_round' : 8,
    'print_times' : False,
    'da' : 'advanced',
    'bs' : 8,
    'nw' : 2,
    'lr' : 0.1,
    'wd' : 0.0001,
    'opt' : 'SGD',
    'm' : 0.9,
    'policy' : 'poly',
    'lr_power' : 0.9,
    'test' : True,
    'warmup' : 0,
    'train_display_interval' : 1,
    'valid_interval' : 5,
    'n_final_rounds' : 5,
    'save_best_model' : True,
    'mode' : 'SL',
}

main(args_dict)
# Out:
#
#
#  #############################################
#
#  I'm in the experiment:
#   Namespace(seed=42, dataset='idda', model='deeplabv3_mobilenetv2', num_rounds=100, num_epochs=3, n_exp=16, clients_per_round=8, print_times=False, target_miou=0.0, da='advanced', bs=8, nw=2, lr=0.1, wd=0.0001, hnm=False, opt='SGD', m=0.9, Adam_p=None, policy='poly', lr_power=0.9, lr_step=15, lr_factor=0.1, test=True, warmup=0, train_display_interval=1, valid_interval=5, n_final_rounds=5, save_best_model=True, mode='SL', teacher_strat=1, T=5, path_model_SSL=None)
# Initializing model...
# Done.
# Generate datasets...
# Done.
#  Round 1/100
#  Client 1/8: T03_CN_A_U1
#  Client 2/8: T02_CN_J_U1
#  Client 3/8: T02_CN_A_U1
#  Client 4/8: T02_CS_J_U1
#  Client 5/8: T02_CS_A_U2
#  Client 6/8: T03_CN_A_U2
#  Client 7/8: T03_CS_J_U2
#  Client 8/8: T02_CN_A_U2
#
#  Results:
# 	 - Round_loss=0.5875039547681808
# 	 - Round_mean_IoU=0.18362518296594987
# 	 - Round_fw_IoU=0.5520797337329784
# ...
