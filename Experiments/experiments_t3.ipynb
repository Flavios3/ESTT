# %%
#Mounting the drive
#import os
#import sys

from google.colab import drive
drive.mount('/content/drive')
# %cd "/content/drive/MyDrive/MLDL-Project/Code/Codebase_inUse"
#sys.path.append(os.path.abspath('Code/Codebase_inUse'))
# Out:
# Mounted at /content/drive
# /content/drive/.shortcut-targets-by-id/1qdeOmMzRTTZYag_nMfIYW1ptaZ_OpJwD/MLDL-Project/Code/Codebase_inUse

# %%
from model_t3 import *

# %% [markdown]
# 1. T3.2:
#   - Train on GTAV
#   - Validate on IDDA training set
#   - Test on IDDA test sets
#
# 2. T3.4:
#   - Repeat T3.2 but implementing FDA for style transfer with various configs of BETA param.
#
# ## Experiments
#
# 1. T3.2:
#   - HPO again: [lr, wd, num_epochs]
#   - Fixed HP: [da, scheduler, optimizer]
#
#     - For all (lr,wd)'s train for 30 epochs
#     - Train the two best models till convergence.
#
# 2. T3.4:
#   - Use the HP found in 1
#   - Empirically analyze how Beta affects the style transfer
#   - Train for 4-5 beta's of the ones that do not allucinate the model
#   - Train the best one till convergence.
#
#
# Time for train epoch: 322 s
#
# Time for valid epoch: 106 s

# %% [markdown]
# # 3.2

# %% [markdown]
# ## Shorter experiments
#
# Train several models under different configurations for a  small number of epochs, to select the best configs.
# In particular
# - train for 20 epochs
# - a configuration is a couple (lr, wd); standard values are considered as possible for those params (for a total of 12 configurations)

# %%
args_dict = {
    'seed' : 42,
    'dataset' : 'gtaV',
    'model' : 'deeplabv3_mobilenetv2',
    'num_epochs' : 20 ,
    'n_exp' : 1,
    'print_times' : True,
    'da' : 'advanced',
    'bs' : 8,
    'nw' : 2,
    'lr': 0.1,
    'wd' : 0.0001,
    'hnm' : False,
    'opt' : 'SGD',
    'm' : 0.9,
    'policy' : 'poly',
    'lr_power' : 0.9,
    'test' : False,
    'warmup' : 0,
    'train_display_interval' : 1,
    'valid_interval' : 1,
    'n_final_epochs' : 1,
    'save_best_model' : False,
    'style_transfer' : False,
    'L' : 0.01,
    'num_images_per_style' : -1
}

# %%
#Exp.1: (lr,wd) = (0.1,0.0001)

experiment_t3(args_dict)
# Out:
#
#
#  #############################################
#
#  I'm in the experiment:
#   Namespace(seed=42, dataset='gtaV', model='deeplabv3_mobilenetv2', num_epochs=20, n_exp=1, print_times=True, da='advanced', bs=8, nw=2, lr=0.1, wd=0.0001, hnm=False, opt='SGD', m=0.9, policy='poly', lr_power=0.9, lr_step=15, lr_factor=0.1, Adam_p=None, test=False, warmup=0, train_display_interval=1, valid_interval=1, n_final_epochs=1, save_best_model=False, style_transfer=False, L=0.01, num_images_per_style=-1)
#  Generating datasets...
#  ...done
#
#
#  Epoch 1/20
#
#  Time for train loop: 75.52 seconds
#
#  Train results for current epoch:
# 	 loss:  0.9998970339375157
# 	 mIoU:  0.18860863853345972
# 	 fwIoU:  0.5310751888401064
# 	 pAcc:  0.24621838670358276
#
#  Validation results:
# 	 - loss=0.8707371481259664
# 	 - mIoU=0.20009809790327826
# 	 - fwIoU=0.584543570441842
# 	 - pAcc=0.2571277223238248
#
#  Time for eval loop: 112.31 seconds
#
#
#  Epoch 2/20
#
#  Time for train loop: 73.45 seconds
# ...

# %%
args_dict['wd'] = 0.00001
args_dict['n_exp'] = 2
experiment_t3(args_dict)
# Out:
#
#
#  #############################################
#
#  I'm in the experiment:
#   Namespace(seed=42, dataset='gtaV', model='deeplabv3_mobilenetv2', num_epochs=20, n_exp=2, print_times=True, da='advanced', bs=8, nw=2, lr=0.1, wd=1e-05, hnm=False, opt='SGD', m=0.9, policy='poly', lr_power=0.9, lr_step=15, lr_factor=0.1, Adam_p=None, test=False, warmup=0, train_display_interval=1, valid_interval=1, n_final_epochs=1, save_best_model=False, style_transfer=False, L=0.01, num_images_per_style=-1)
#  Generating datasets...
#  ...done
#
#
#  Epoch 1/20
#
#  Time for train loop: 69.40 seconds
#
#  Train results for current epoch:
# 	 loss:  0.9950889743143513
# 	 mIoU:  0.18925495883825913
# 	 fwIoU:  0.5341030816688227
# 	 pAcc:  0.24707290220960354
#
#  Validation results:
# 	 - loss=1.0239658641815186
# 	 - mIoU=0.1588569677395491
# 	 - fwIoU=0.44596762063347867
# 	 - pAcc=0.2254323403756892
#
#  Time for eval loop: 106.02 seconds
#
#
#  Epoch 2/20
#
#  Time for train loop: 70.45 seconds
# ...

# %%
args_dict['wd'] = 0
args_dict['n_exp'] = 3
experiment_t3(args_dict)
# Out:
#
#
#  #############################################
#
#  I'm in the experiment:
#   Namespace(seed=42, dataset='gtaV', model='deeplabv3_mobilenetv2', num_epochs=20, n_exp=3, print_times=True, da='advanced', bs=8, nw=2, lr=0.1, wd=0, hnm=False, opt='SGD', m=0.9, policy='poly', lr_power=0.9, lr_step=15, lr_factor=0.1, Adam_p=None, test=False, warmup=0, train_display_interval=1, valid_interval=1, n_final_epochs=1, save_best_model=False, style_transfer=False, L=0.01, num_images_per_style=-1)
#  Generating datasets...
#  ...done
#
#
#  Epoch 1/20
#
#  Time for train loop: 69.93 seconds
#
#  Train results for current epoch:
# 	 loss:  1.0681466969751543
# 	 mIoU:  0.17827900324456086
# 	 fwIoU:  0.5064937494095069
# 	 pAcc:  0.2358757965619577
#
#  Validation results:
# 	 - loss=2.143474939664205
# 	 - mIoU=0.07130688646637784
# 	 - fwIoU=0.16169503457111678
# 	 - pAcc=0.15041865652780628
#
#  Time for eval loop: 107.07 seconds
#
#
#  Epoch 2/20
#
#  Time for train loop: 72.69 seconds
#
# ...

# %%
args_dict['lr'] = 0.01
args_dict['wd'] = 0.0001
args_dict['n_exp'] = 4
experiment_t3(args_dict)
# Out:
#
#
#  #############################################
#
#  I'm in the experiment:
#   Namespace(seed=42, dataset='gtaV', model='deeplabv3_mobilenetv2', num_epochs=20, n_exp=4, print_times=True, da='advanced', bs=8, nw=2, lr=0.01, wd=0.0001, hnm=False, opt='SGD', m=0.9, policy='poly', lr_power=0.9, lr_step=15, lr_factor=0.1, Adam_p=None, test=False, warmup=0, train_display_interval=1, valid_interval=1, n_final_epochs=1, save_best_model=False, style_transfer=False, L=0.01, num_images_per_style=-1)
#  Generating datasets...
#  ...done
#
#
#  Epoch 1/20
#
#  Time for train loop: 69.06 seconds
#
#  Train results for current epoch:
# 	 loss:  0.9675669112513142
# 	 mIoU:  0.19975591921935112
# 	 fwIoU:  0.558182592273619
# 	 pAcc:  0.2524314039678073
#
#  Validation results:
# 	 - loss=0.9834166590372722
# 	 - mIoU=0.19160321373467737
# 	 - fwIoU=0.4969596963705415
# 	 - pAcc=0.2692144800618787
#
#  Time for eval loop: 105.68 seconds
#
#
#  Epoch 2/20
#
#  Time for train loop: 71.75 seconds
# ...

# %%
args_dict['wd'] = 0.00001
args_dict['n_exp'] = 5
experiment_t3(args_dict)
# Out:
#
#
#  #############################################
#
#  I'm in the experiment:
#   Namespace(seed=42, dataset='gtaV', model='deeplabv3_mobilenetv2', num_epochs=20, n_exp=5, print_times=True, da='advanced', bs=8, nw=2, lr=0.01, wd=1e-05, hnm=False, opt='SGD', m=0.9, policy='poly', lr_power=0.9, lr_step=15, lr_factor=0.1, Adam_p=None, test=False, warmup=0, train_display_interval=1, valid_interval=1, n_final_epochs=1, save_best_model=False, style_transfer=False, L=0.01, num_images_per_style=-1)
#  Generating datasets...
#  ...done
#
#
#  Epoch 1/20
#
#  Time for train loop: 68.00 seconds
#
#  Train results for current epoch:
# 	 loss:  0.9662122615883427
# 	 mIoU:  0.20032109704457612
# 	 fwIoU:  0.5596642575415305
# 	 pAcc:  0.2529488021834808
#
#  Validation results:
# 	 - loss=0.8504227542877197
# 	 - mIoU=0.2174289123575675
# 	 - fwIoU=0.5845562513347037
# 	 - pAcc=0.28621505588567975
#
#  Time for eval loop: 103.31 seconds
#
#
#  Epoch 2/20
#
#  Time for train loop: 69.12 seconds
# ...

# %%
args_dict['lr'] = 0.01
args_dict['wd'] = 0
args_dict['n_exp'] = 6
experiment_t3(args_dict)
# Out:
#
#
#  #############################################
#
#  I'm in the experiment:
#   Namespace(seed=42, dataset='gtaV', model='deeplabv3_mobilenetv2', num_epochs=20, n_exp=6, print_times=True, da='advanced', bs=8, nw=2, lr=0.01, wd=0, hnm=False, opt='SGD', m=0.9, policy='poly', lr_power=0.9, lr_step=15, lr_factor=0.1, Adam_p=None, test=False, warmup=0, train_display_interval=1, valid_interval=1, n_final_epochs=1, save_best_model=False, style_transfer=False, L=0.01, num_images_per_style=-1)
# Downloading: "https://github.com/d-li14/mobilenetv2.pytorch/raw/master/pretrained/mobilenetv2_1.0-0c6065bc.pth" to /root/.cache/torch/hub/checkpoints/mobilenetv2_1.0-0c6065bc.pth
# 100%|██████████| 13.5M/13.5M [00:00<00:00, 261MB/s]
#  Generating datasets...
#  ...done
#
#
#  Epoch 1/20
#
#  Time for train loop: 252.55 seconds
#
#  Train results for current epoch:
# 	 loss:  0.9668817520141602
# 	 mIoU:  0.20014824470328527
# 	 fwIoU:  0.5590307787095274
# 	 pAcc:  0.25282140278899334
#
# ...

# %%
args_dict['lr'] = 0.001
args_dict['wd'] = 0.0001
args_dict['n_exp'] = 7
experiment_t3(args_dict)
# Out:
#
#
#  #############################################
#
#  I'm in the experiment:
#   Namespace(seed=42, dataset='gtaV', model='deeplabv3_mobilenetv2', num_epochs=20, n_exp=7, print_times=True, da='advanced', bs=8, nw=2, lr=0.001, wd=0.0001, hnm=False, opt='SGD', m=0.9, policy='poly', lr_power=0.9, lr_step=15, lr_factor=0.1, Adam_p=None, test=False, warmup=0, train_display_interval=1, valid_interval=1, n_final_epochs=1, save_best_model=False, style_transfer=False, L=0.01, num_images_per_style=-1)
#  Generating datasets...
#  ...done
#
#
#  Epoch 1/20
#
#  Time for train loop: 70.10 seconds
#
#  Train results for current epoch:
# 	 loss:  1.7422947345241424
# 	 mIoU:  0.10507811272773629
# 	 fwIoU:  0.3494016496601816
# 	 pAcc:  0.1504178126365049
#
#  Validation results:
# 	 - loss=1.2301561617851258
# 	 - mIoU=0.16975078386304138
# 	 - fwIoU=0.5099915546878583
# 	 - pAcc=0.24056950617317713
#
#  Time for eval loop: 104.95 seconds
#
#
#  Epoch 2/20
#
# ...

# %%
args_dict['wd'] = 0.00001
args_dict['n_exp'] = 8
experiment_t3(args_dict)
# Out:
#
#
#  #############################################
#
#  I'm in the experiment:
#   Namespace(seed=42, dataset='gtaV', model='deeplabv3_mobilenetv2', num_epochs=20, n_exp=8, print_times=True, da='advanced', bs=8, nw=2, lr=0.001, wd=1e-05, hnm=False, opt='SGD', m=0.9, policy='poly', lr_power=0.9, lr_step=15, lr_factor=0.1, Adam_p=None, test=False, warmup=0, train_display_interval=1, valid_interval=1, n_final_epochs=1, save_best_model=False, style_transfer=False, L=0.01, num_images_per_style=-1)
#  Generating datasets...
#  ...done
#
#
#  Epoch 1/20
#
#  Time for train loop: 70.05 seconds
#
#  Train results for current epoch:
# 	 loss:  1.7422398953668532
# 	 mIoU:  0.10506904026368825
# 	 fwIoU:  0.34939462784489694
# 	 pAcc:  0.15040948341665247
#
#  Validation results:
# 	 - loss=1.2270570492744446
# 	 - mIoU=0.16997190374492074
# 	 - fwIoU=0.510679829523547
# 	 - pAcc=0.24064887331928803
#
#  Time for eval loop: 107.36 seconds
#
#
#  Epoch 2/20
#
# ...

# %%
args_dict['wd'] = 0
args_dict['n_exp'] = 9
experiment_t3(args_dict)
# Out:
#
#
#  #############################################
#
#  I'm in the experiment:
#   Namespace(seed=42, dataset='gtaV', model='deeplabv3_mobilenetv2', num_epochs=20, n_exp=9, print_times=True, da='advanced', bs=8, nw=2, lr=0.1, wd=0, hnm=False, opt='SGD', m=0.9, policy='poly', lr_power=0.9, lr_step=15, lr_factor=0.1, Adam_p=None, test=False, warmup=0, train_display_interval=1, valid_interval=1, n_final_epochs=1, save_best_model=False, style_transfer=False, L=0.01, num_images_per_style=-1)
# Downloading: "https://github.com/d-li14/mobilenetv2.pytorch/raw/master/pretrained/mobilenetv2_1.0-0c6065bc.pth" to /root/.cache/torch/hub/checkpoints/mobilenetv2_1.0-0c6065bc.pth
# 100%|██████████| 13.5M/13.5M [00:00<00:00, 208MB/s]
#  Generating datasets...
#  ...done
#
#
#  Epoch 1/20
#
#  Time for train loop: 489.89 seconds
#
#  Train results for current epoch:
# 	 loss:  0.9728962058021177
# 	 mIoU:  0.19493786802272603
# 	 fwIoU:  0.5438752507729713
# 	 pAcc:  0.25318954688191614
#
# ...

# %%
args_dict['lr'] = 0.0001
args_dict['wd'] = 0.0001
args_dict['n_exp'] = 10
experiment_t3(args_dict)
# Out:
#
#
#  #############################################
#
#  I'm in the experiment:
#   Namespace(seed=42, dataset='gtaV', model='deeplabv3_mobilenetv2', num_epochs=20, n_exp=10, print_times=True, da='advanced', bs=8, nw=2, lr=0.0001, wd=0.0001, hnm=False, opt='SGD', m=0.9, policy='poly', lr_power=0.9, lr_step=15, lr_factor=0.1, Adam_p=None, test=False, warmup=0, train_display_interval=1, valid_interval=1, n_final_epochs=1, save_best_model=False, style_transfer=False, L=0.01, num_images_per_style=-1)
# Downloading: "https://github.com/d-li14/mobilenetv2.pytorch/raw/master/pretrained/mobilenetv2_1.0-0c6065bc.pth" to /root/.cache/torch/hub/checkpoints/mobilenetv2_1.0-0c6065bc.pth
# 100%|██████████| 13.5M/13.5M [00:00<00:00, 259MB/s]
#  Generating datasets...
#  ...done
#
#
#  Epoch 1/20
#
#  Time for train loop: 241.65 seconds
#
#  Train results for current epoch:
# 	 loss:  2.684406945782323
# 	 mIoU:  0.03718626783172291
# 	 fwIoU:  0.13541511524255986
# 	 pAcc:  0.10065375731542664
#
# ...

# %%
args_dict['wd'] = 0.00001
args_dict['n_exp'] = 11
experiment_t3(args_dict)
# Out:
#
#
#  #############################################
#
#  I'm in the experiment:
#   Namespace(seed=42, dataset='gtaV', model='deeplabv3_mobilenetv2', num_epochs=20, n_exp=11, print_times=True, da='advanced', bs=8, nw=2, lr=0.1, wd=1e-05, hnm=False, opt='SGD', m=0.9, policy='poly', lr_power=0.9, lr_step=15, lr_factor=0.1, Adam_p=None, test=False, warmup=0, train_display_interval=1, valid_interval=1, n_final_epochs=1, save_best_model=False, style_transfer=False, L=0.01, num_images_per_style=-1)
# Downloading: "https://github.com/d-li14/mobilenetv2.pytorch/raw/master/pretrained/mobilenetv2_1.0-0c6065bc.pth" to /root/.cache/torch/hub/checkpoints/mobilenetv2_1.0-0c6065bc.pth
# 100%|██████████| 13.5M/13.5M [00:00<00:00, 176MB/s]
#  Generating datasets...
#  ...done
#
#
#  Epoch 1/20
#
#  Time for train loop: 212.86 seconds
#
#  Train results for current epoch:
# 	 loss:  1.0391084792152527
# 	 mIoU:  0.18349685617335756
# 	 fwIoU:  0.5198662471375838
# 	 pAcc:  0.24080149783366042
#
# ...

# %%
args_dict['wd'] = 0
args_dict['n_exp'] = 12
experiment_t3(args_dict)
# Out:
#
#
#  #############################################
#
#  I'm in the experiment:
#   Namespace(seed=42, dataset='gtaV', model='deeplabv3_mobilenetv2', num_epochs=20, n_exp=12, print_times=True, da='advanced', bs=8, nw=2, lr=0.1, wd=0, hnm=False, opt='SGD', m=0.9, policy='poly', lr_power=0.9, lr_step=15, lr_factor=0.1, Adam_p=None, test=False, warmup=0, train_display_interval=1, valid_interval=1, n_final_epochs=1, save_best_model=False, style_transfer=False, L=0.01, num_images_per_style=-1)
#  Generating datasets...
#  ...done
#
#
#  Epoch 1/20
#
#  Time for train loop: 71.79 seconds
#
#  Train results for current epoch:
# 	 loss:  0.9700665887325041
# 	 mIoU:  0.19075457467957235
# 	 fwIoU:  0.5371716632542513
# 	 pAcc:  0.2478938068709855
#
#  Validation results:
# 	 - loss=1.146824422677358
# 	 - mIoU=0.18017159852163916
# 	 - fwIoU=0.49714432993048935
# 	 - pAcc=0.2546676945625351
#
#  Time for eval loop: 110.59 seconds
#
#
#  Epoch 2/20
#
#  Time for train loop: 72.72 seconds
#
# ...

# %% [markdown]
# ## Long experiments
#
# Training the best models for several epochs
# Selected configurations:
#   - (lr,wd) = (0.1,0.00001)
#   - (lr,wd) = (0.01, 0.00001)
#   - (lr,wd) = (0.01, 0.00001) with cosine annealing
#
# Time for:
# - train: 70s
# - eval: 110s
#
# quindi 92s per epoch
#
# 8h = 28800s = 313 epoch crc

# %%
args_dict = {
    'seed' : 42,
    'dataset' : 'gtaV',
    'model' : 'deeplabv3_mobilenetv2',
    'num_epochs' : 300 ,
    'n_exp' : 13,
    'print_times' : True,
    'da' : 'advanced',
    'bs' : 8,
    'nw' : 2,
    'lr': 0.1,
    'wd' : 0.00001,
    'hnm' : False,
    'opt' : 'SGD',
    'm' : 0.9,
    'policy' : 'poly',
    'lr_power' : 0.9,
    'test' : True,
    'warmup' : 0,
    'train_display_interval' : 5,
    'valid_interval' :  10,
    'n_final_epochs' :  10,
    'save_best_model' : True,
    'style_transfer' : False,
    'L' : 0.01,
    'num_images_per_style' : -1
}

experiment_t3(args_dict)
# Out:
#
#
#  #############################################
#
#  I'm in the experiment:
#   Namespace(seed=42, dataset='gtaV', model='deeplabv3_mobilenetv2', num_epochs=300, n_exp=13, print_times=True, da='advanced', bs=8, nw=2, lr=0.1, wd=1e-05, hnm=False, opt='SGD', m=0.9, policy='poly', lr_power=0.9, lr_step=15, lr_factor=0.1, Adam_p=None, test=True, warmup=0, train_display_interval=5, valid_interval=10, n_final_epochs=10, save_best_model=True, style_transfer=False, L=0.01, num_images_per_style=-1)
#  Generating datasets...
#  ...done
#
#
#  Epoch 1/300
#
#  Time for train loop: 72.75 seconds
#
#
#  Epoch 2/300
#
#  Time for train loop: 70.56 seconds
#
#
#  Epoch 3/300
#
#  Time for train loop: 67.71 seconds
#
#
#  Epoch 4/300
#
#  Time for train loop: 68.06 seconds
#
#
#  Epoch 5/300
#
#  Time for train loop: 68.06 seconds
#
#  Train results for current epoch:
# 	 loss:  0.5062447195091555
# 	 mIoU:  0.295412122257675
# 	 fwIoU:  0.7257215166390331
# 	 pAcc:  0.3527505844162613
#
#
# ...

# %%
args_dict = {
    'seed' : 42,
    'dataset' : 'gtaV',
    'model' : 'deeplabv3_mobilenetv2',
    'num_epochs' : 300 ,
    'n_exp' : 14,
    'print_times' : True,
    'da' : 'advanced',
    'bs' : 8,
    'nw' : 2,
    'lr': 0.01,
    'wd' : 0.00001,
    'hnm' : False,
    'opt' : 'SGD',
    'm' : 0.9,
    'policy' : 'poly',
    'lr_power' : 0.9,
    'test' : True,
    'warmup' : 0,
    'train_display_interval' : 5,
    'valid_interval' :  10,
    'n_final_epochs' :  10,
    'save_best_model' : True,
    'style_transfer' : False,
    'L' : 0.01,
    'num_images_per_style' : -1
}

experiment_t3(args_dict)
# Out:
#
#
#  #############################################
#
#  I'm in the experiment:
#   Namespace(seed=42, dataset='gtaV', model='deeplabv3_mobilenetv2', num_epochs=300, n_exp=14, print_times=True, da='advanced', bs=8, nw=2, lr=0.01, wd=1e-05, hnm=False, opt='SGD', m=0.9, policy='poly', lr_power=0.9, lr_step=15, lr_factor=0.1, Adam_p=None, test=True, warmup=0, train_display_interval=5, valid_interval=10, n_final_epochs=10, save_best_model=True, style_transfer=False, L=0.01, num_images_per_style=-1)
# Downloading: "https://github.com/d-li14/mobilenetv2.pytorch/raw/master/pretrained/mobilenetv2_1.0-0c6065bc.pth" to /root/.cache/torch/hub/checkpoints/mobilenetv2_1.0-0c6065bc.pth
# 100%|██████████| 13.5M/13.5M [00:00<00:00, 335MB/s]
#  Generating datasets...
#  ...done
#
#
#  Epoch 1/300
#
#  Time for train loop: 500.78 seconds
#
#
#  Epoch 2/300
#
#  Time for train loop: 67.70 seconds
#
#
#  Epoch 3/300
#
#  Time for train loop: 66.66 seconds
#
#
#  Epoch 4/300
#
# ...

# %%
args_dict = {
    'seed' : 42,
    'dataset' : 'gtaV',
    'model' : 'deeplabv3_mobilenetv2',
    'num_epochs' : 300 ,
    'n_exp' : 15,
    'print_times' : True,
    'da' : 'advanced',
    'bs' : 8,
    'nw' : 2,
    'lr': 0.01,
    'wd' : 0.00001,
    'hnm' : False,
    'opt' : 'SGD',
    'm' : 0.9,
    'policy' : 'cosine',
    'test' : True,
    'warmup' : 0,
    'train_display_interval' : 5,
    'valid_interval' :  10,
    'n_final_epochs' :  10,
    'save_best_model' : True,
    'style_transfer' : False,
    'L' : 0.01,
    'num_images_per_style' : -1
}

experiment_t3(args_dict)
# Out:
#
#
#  #############################################
#
#  I'm in the experiment:
#   Namespace(seed=42, dataset='gtaV', model='deeplabv3_mobilenetv2', num_epochs=300, n_exp=16, print_times=True, da='advanced', bs=8, nw=2, lr=0.1, wd=1e-05, hnm=False, opt='SGD', m=0.9, policy='cosine', lr_power=0.9, lr_step=15, lr_factor=0.1, Adam_p=None, test=True, warmup=0, train_display_interval=5, valid_interval=10, n_final_epochs=10, save_best_model=True, style_transfer=False, L=0.01, num_images_per_style=-1)
#  Generating datasets...
#  ...done
#
#
#  Epoch 1/300
#
#  Time for train loop: 185.14 seconds
#
#
#  Epoch 2/300
#
#  Time for train loop: 68.85 seconds
#
#
#  Epoch 3/300
#
#  Time for train loop: 68.69 seconds
#
#
#  Epoch 4/300
#
#  Time for train loop: 70.59 seconds
#
#
#  Epoch 5/300
#
#  Time for train loop: 68.90 seconds
#
#  Train results for current epoch:
# 	 loss:  0.5276640379621137
# 	 mIoU:  0.28572391616585296
# 	 fwIoU:  0.7146821981736692
# 	 pAcc:  0.3433366476371144
#
#
# ...

# %% [markdown]
# # 3.4
#
# - Time for train epoch: 240s
# - Time for valid epoch: 110s
# - Adjusted time for epoch: 262s
#
# - 10 epoch -> 43 min
# - 8h = 28800s -> 110
#
# Thus
# - short experiments (tune beta): 20 epochs
# - long experiment (best beta): 100 epochs

# %% [markdown]
# ## Short experiments (tuning beta)

# %%
args_dict = {
    'seed' : 42,
    'dataset' : 'gtaV',
    'model' : 'deeplabv3_mobilenetv2',
    'num_epochs' : 20,
    'n_exp' : 16,
    'print_times' : True,
    'da' : 'advanced',
    'bs' : 8,
    'nw' : 2,
    'lr': 0.01,
    'wd' : 0.00001,
    'hnm' : False,
    'opt' : 'SGD',
    'm' : 0.9,
    'policy' : 'poly',
    'test' : True,
    'warmup' : 0,
    'train_display_interval' : 1,
    'valid_interval' :  2,
    'n_final_epochs' :  1,
    'save_best_model' : False,
    'style_transfer' : True,
    'L' : 0.000001,
    'num_images_per_style' : 5
}

experiment_t3(args_dict)
# Out:
#
#
#  #############################################
#
#  I'm in the experiment:
#   Namespace(seed=42, dataset='gtaV', model='deeplabv3_mobilenetv2', num_epochs=20, n_exp=16, print_times=True, da='advanced', bs=8, nw=2, lr=0.01, wd=1e-05, hnm=False, opt='SGD', m=0.9, policy='poly', lr_power=0.9, lr_step=15, lr_factor=0.1, Adam_p=None, test=True, warmup=0, train_display_interval=1, valid_interval=2, n_final_epochs=1, save_best_model=False, style_transfer=True, L=1e-06, num_images_per_style=5)
# Downloading: "https://github.com/d-li14/mobilenetv2.pytorch/raw/master/pretrained/mobilenetv2_1.0-0c6065bc.pth" to /root/.cache/torch/hub/checkpoints/mobilenetv2_1.0-0c6065bc.pth
# 100%|██████████| 13.5M/13.5M [00:00<00:00, 290MB/s]
#  Generating datasets...
#  ...done
#  Creating the styles
# ...
# 100%|██████████| 5/5 [00:11<00:00,  2.36s/it]
#  Finished!
#
#
#  Epoch 1/20
#  Time for train loop: 624.42 seconds
#
#  Train results for current epoch:
# 	 loss:  1.0042006801212988
# ...

# %%
args_dict['n_exp'] = 17
args_dict['L'] = 0.0001

experiment_t3(args_dict)
# Out:
#
#
#  #############################################
#
#  I'm in the experiment:
#   Namespace(seed=42, dataset='gtaV', model='deeplabv3_mobilenetv2', num_epochs=20, n_exp=17, print_times=True, da='advanced', bs=8, nw=2, lr=0.01, wd=1e-05, hnm=False, opt='SGD', m=0.9, policy='poly', lr_power=0.9, lr_step=15, lr_factor=0.1, Adam_p=None, test=True, warmup=0, train_display_interval=1, valid_interval=2, n_final_epochs=1, save_best_model=False, style_transfer=True, L=0.0001, num_images_per_style=5)
#  Generating datasets...
#  ...done
#  Creating the styles
# ...
# 100%|██████████| 5/5 [00:01<00:00,  4.86it/s]
#  Finished!
#
#
#  Epoch 1/20
#  Time for train loop: 227.06 seconds
#
#  Train results for current epoch:
# 	 loss:  1.001918716296073
# 	 mIoU:  0.19317698337189262
# 	 fwIoU:  0.5440487479909026
# 	 pAcc:  0.24609939324270186
#
#
#  Epoch 2/20
#
#  Time for train loop: 227.86 seconds
#
#  Train results for current epoch:
# 	 loss:  0.5737902916246845
# 	 mIoU:  0.26186528647403373
# ...

# %%
args_dict['n_exp'] = 18
args_dict['L'] = 0.001

experiment_t3(args_dict)
# Out:
#
#
#  #############################################
#
#  I'm in the experiment:
#   Namespace(seed=42, dataset='gtaV', model='deeplabv3_mobilenetv2', num_epochs=20, n_exp=18, print_times=True, da='advanced', bs=8, nw=2, lr=0.01, wd=1e-05, hnm=False, opt='SGD', m=0.9, policy='poly', lr_power=0.9, lr_step=15, lr_factor=0.1, Adam_p=None, test=True, warmup=0, train_display_interval=1, valid_interval=2, n_final_epochs=1, save_best_model=False, style_transfer=True, L=0.001, num_images_per_style=5)
# Downloading: "https://github.com/d-li14/mobilenetv2.pytorch/raw/master/pretrained/mobilenetv2_1.0-0c6065bc.pth" to /root/.cache/torch/hub/checkpoints/mobilenetv2_1.0-0c6065bc.pth
# 100%|██████████| 13.5M/13.5M [00:00<00:00, 196MB/s]
#  Generating datasets...
#  ...done
#  Creating the styles
# ...
# 100%|██████████| 5/5 [00:05<00:00,  1.02s/it]
#  Finished!
#
#
#  Epoch 1/20
#  Time for train loop: 386.22 seconds
#
#  Train results for current epoch:
# 	 loss:  1.001410244453338
# ...

# %%
args_dict['n_exp'] = 19
args_dict['L'] = 0.01

experiment_t3(args_dict)
# Out:
#
#
#  #############################################
#
#  I'm in the experiment:
#   Namespace(seed=42, dataset='gtaV', model='deeplabv3_mobilenetv2', num_epochs=20, n_exp=19, print_times=True, da='advanced', bs=8, nw=2, lr=0.01, wd=1e-05, hnm=False, opt='SGD', m=0.9, policy='poly', lr_power=0.9, lr_step=15, lr_factor=0.1, Adam_p=None, test=True, warmup=0, train_display_interval=1, valid_interval=2, n_final_epochs=1, save_best_model=False, style_transfer=True, L=0.01, num_images_per_style=5)
#  Generating datasets...
#  ...done
#  Creating the styles
# ...
# 100%|██████████| 5/5 [00:00<00:00,  5.70it/s]
#  Finished!
#
#
#  Epoch 1/20
#  Time for train loop: 238.97 seconds
#
#  Train results for current epoch:
# 	 loss:  1.0099282038788642
# 	 mIoU:  0.1928067563994534
# 	 fwIoU:  0.5421453574870022
# 	 pAcc:  0.2454563977094294
#
#
#  Epoch 2/20
#
#  Time for train loop: 243.32 seconds
#
#  Train results for current epoch:
# 	 loss:  0.584991497858878
# 	 mIoU:  0.2555458244972531
# ...

# %%
args_dict['n_exp'] = 20
args_dict['L'] = 0.05

experiment_t3(args_dict)
# Out:
#
#
#  #############################################
#
#  I'm in the experiment:
#   Namespace(seed=42, dataset='gtaV', model='deeplabv3_mobilenetv2', num_epochs=20, n_exp=20, print_times=True, da='advanced', bs=8, nw=2, lr=0.01, wd=1e-05, hnm=False, opt='SGD', m=0.9, policy='poly', lr_power=0.9, lr_step=15, lr_factor=0.1, Adam_p=None, test=True, warmup=0, train_display_interval=1, valid_interval=2, n_final_epochs=1, save_best_model=False, style_transfer=True, L=0.05, num_images_per_style=5)
# Downloading: "https://github.com/d-li14/mobilenetv2.pytorch/raw/master/pretrained/mobilenetv2_1.0-0c6065bc.pth" to /root/.cache/torch/hub/checkpoints/mobilenetv2_1.0-0c6065bc.pth
# 100%|██████████| 13.5M/13.5M [00:00<00:00, 181MB/s]
#  Generating datasets...
#  ...done
#  Creating the styles
# ...
# 100%|██████████| 5/5 [00:04<00:00,  1.24it/s]
#  Finished!
#
#
#  Epoch 1/20
#  Time for train loop: 319.26 seconds
#
#  Train results for current epoch:
# 	 loss:  1.0327375516776116
# ...

# %%
args_dict['n_exp'] = 21
args_dict['L'] = 0.3

experiment_t3(args_dict)
# Out:
#
#
#  #############################################
#
#  I'm in the experiment:
#   Namespace(seed=42, dataset='gtaV', model='deeplabv3_mobilenetv2', num_epochs=20, n_exp=21, print_times=True, da='advanced', bs=8, nw=2, lr=0.01, wd=1e-05, hnm=False, opt='SGD', m=0.9, policy='poly', lr_power=0.9, lr_step=15, lr_factor=0.1, Adam_p=None, test=True, warmup=0, train_display_interval=1, valid_interval=2, n_final_epochs=1, save_best_model=False, style_transfer=True, L=0.3, num_images_per_style=5)
#  Generating datasets...
#  ...done
#  Creating the styles
# ...
# 100%|██████████| 5/5 [00:00<00:00,  6.09it/s]
#  Finished!
#
#
#  Epoch 1/20
#  Time for train loop: 221.64 seconds
#
#  Train results for current epoch:
# 	 loss:  1.1312780457158242
# 	 mIoU:  0.170820328623864
# 	 fwIoU:  0.49291247451816866
# 	 pAcc:  0.2240468157848002
#
#
#  Epoch 2/20
#
#  Time for train loop: 219.11 seconds
#
#  Train results for current epoch:
# 	 loss:  0.6751704268878506
# 	 mIoU:  0.23520630568590664
# ...

# %% [markdown]
# ## Some further tuning for beta

# %%
args_dict = {
    'seed' : 42,
    'dataset' : 'gtaV',
    'model' : 'deeplabv3_mobilenetv2',
    'num_epochs' : 20,
    'n_exp' : 22,
    'print_times' : True,
    'da' : 'advanced',
    'bs' : 8,
    'nw' : 2,
    'lr': 0.01,
    'wd' : 0.00001,
    'hnm' : False,
    'opt' : 'SGD',
    'm' : 0.9,
    'policy' : 'poly',
    'test' : True,
    'warmup' : 0,
    'train_display_interval' : 1,
    'valid_interval' :  2,
    'n_final_epochs' :  1,
    'save_best_model' : False,
    'style_transfer' : True,
    'L' : 0.00001,
    'num_images_per_style' : 5
}

experiment_t3(args_dict)
# Out:
#
#
#  #############################################
#
#  I'm in the experiment:
#   Namespace(seed=42, dataset='gtaV', model='deeplabv3_mobilenetv2', num_epochs=20, n_exp=22, print_times=True, da='advanced', bs=8, nw=2, lr=0.01, wd=1e-05, hnm=False, opt='SGD', m=0.9, policy='poly', lr_power=0.9, lr_step=15, lr_factor=0.1, Adam_p=None, test=True, warmup=0, train_display_interval=1, valid_interval=2, n_final_epochs=1, save_best_model=False, style_transfer=True, L=1e-05, num_images_per_style=5)
# Downloading: "https://github.com/d-li14/mobilenetv2.pytorch/raw/master/pretrained/mobilenetv2_1.0-0c6065bc.pth" to /root/.cache/torch/hub/checkpoints/mobilenetv2_1.0-0c6065bc.pth
# 100%|██████████| 13.5M/13.5M [00:00<00:00, 329MB/s]
#  Generating datasets...
#  ...done
#  Creating the styles
# ...
# 100%|██████████| 5/5 [00:03<00:00,  1.36it/s]
#  Finished!
#
#
#  Epoch 1/20
#  Time for train loop: 326.89 seconds
#
#  Train results for current epoch:
# 	 loss:  1.0043080492365746
# ...

# %%
args_dict['n_exp'] = 23
args_dict['L'] = 0.0000001

experiment_t3(args_dict)
# Out:
#
#
#  #############################################
#
#  I'm in the experiment:
#   Namespace(seed=42, dataset='gtaV', model='deeplabv3_mobilenetv2', num_epochs=20, n_exp=23, print_times=True, da='advanced', bs=8, nw=2, lr=0.01, wd=1e-05, hnm=False, opt='SGD', m=0.9, policy='poly', lr_power=0.9, lr_step=15, lr_factor=0.1, Adam_p=None, test=True, warmup=0, train_display_interval=1, valid_interval=2, n_final_epochs=1, save_best_model=False, style_transfer=True, L=1e-07, num_images_per_style=5)
#  Generating datasets...
#  ...done
#  Creating the styles
# ...
# 100%|██████████| 5/5 [00:00<00:00,  5.72it/s]
#  Finished!
#
#
#  Epoch 1/20
#  Time for train loop: 237.13 seconds
#
#  Train results for current epoch:
# 	 loss:  1.0020864038698134
# 	 mIoU:  0.19284789876179356
# 	 fwIoU:  0.543580379029772
# 	 pAcc:  0.24584715323707773
#
#
#  Epoch 2/20
#
#  Time for train loop: 238.24 seconds
#
#  Train results for current epoch:
# 	 loss:  0.5764266862984626
# 	 mIoU:  0.26144086448579096
# ...

# %% [markdown]
# ## Long experiment

# %%
# !cp -r "/content/drive/MyDrive/MLDL-Project/Code/Codebase_inUse/data" "/content/"
# %cd "/content/"
# Out:
# /content

# %%
# !ls
# Out:
# data  drive  sample_data

# %%
args_dict = {
    'seed' : 42,
    'dataset' : 'gtaV',
    'model' : 'deeplabv3_mobilenetv2',
    'num_epochs' : 100,
    'n_exp' : 24,
    'print_times' : True,
    'da' : 'advanced',
    'bs' : 8,
    'nw' : 2,
    'lr': 0.01,
    'wd' : 0.00001,
    'hnm' : False,
    'opt' : 'SGD',
    'm' : 0.9,
    'policy' : 'poly',
    'test' : True,
    'warmup' : 0,
    'train_display_interval' : 1,
    'valid_interval' :  10,
    'n_final_epochs' :  5,
    'save_best_model' : True,
    'style_transfer' : True,
    'L' : 0.000001,
    'num_images_per_style' : -1
}

experiment_t3(args_dict)

# !cp -r "/content/Results/Best_Models/T3/"* "/content/drive/MyDrive/MLDL-Project/Code/Codebase_inUse/Results/Best_Models/T3/"
# !cp -r "/content/Results/Plots/Plots_T3/"* "/content/drive/MyDrive/MLDL-Project/Code/Codebase_inUse/Results/Plots/Plots_T3/"
# Out:
#
#
#  #############################################
#
#  I'm in the experiment:
#   Namespace(seed=42, dataset='gtaV', model='deeplabv3_mobilenetv2', num_epochs=100, n_exp=22, print_times=True, da='advanced', bs=8, nw=2, lr=0.01, wd=1e-05, hnm=False, opt='SGD', m=0.9, policy='poly', lr_power=0.9, lr_step=15, lr_factor=0.1, Adam_p=None, test=True, warmup=0, train_display_interval=1, valid_interval=10, n_final_epochs=5, save_best_model=True, style_transfer=True, L=1e-06, num_images_per_style=-1)
# Downloading: "https://github.com/d-li14/mobilenetv2.pytorch/raw/master/pretrained/mobilenetv2_1.0-0c6065bc.pth" to /root/.cache/torch/hub/checkpoints/mobilenetv2_1.0-0c6065bc.pth
# 100%|██████████| 13.5M/13.5M [00:00<00:00, 133MB/s]
#  Generating datasets...
#  ...done
#  Creating the styles
# ...
# 100%|██████████| 25/25 [00:04<00:00,  6.16it/s]
#  Finished!
#
#
#  Epoch 1/100
#  Time for train loop: 245.98 seconds
#
#  Train results for current epoch:
# 	 loss:  1.00482530651554
# ...

# %%
args_dict = {
    'seed' : 42,
    'dataset' : 'gtaV',
    'model' : 'deeplabv3_mobilenetv2',
    'num_epochs' : 100,
    'n_exp' : 27,
    'print_times' : True,
    'da' : 'advanced',
    'bs' : 8,
    'nw' : 2,
    'lr': 0.01,
    'wd' : 0.00001,
    'hnm' : False,
    'opt' : 'SGD',
    'm' : 0.9,
    'policy' : 'poly',
    'test' : True,
    'warmup' : 0,
    'train_display_interval' : 1,
    'valid_interval' :  10,
    'n_final_epochs' :  5,
    'save_best_model' : True,
    'style_transfer' : True,
    'L' : 0.0001,
    'num_images_per_style' : -1
}

experiment_t3(args_dict)

# !cp -r "/content/Results/Best_Models/T3/"* "/content/drive/MyDrive/MLDL-Project/Code/Codebase_inUse/Results/Best_Models/T3/"
# !cp -r "/content/Results/Plots/Plots_T3/"* "/content/drive/MyDrive/MLDL-Project/Code/Codebase_inUse/Results/Plots/Plots_T3/"
# Out:
#
#
#  #############################################
#
#  I'm in the experiment:
#   Namespace(seed=42, dataset='gtaV', model='deeplabv3_mobilenetv2', num_epochs=100, n_exp=27, print_times=True, da='advanced', bs=8, nw=2, lr=0.01, wd=1e-05, hnm=False, opt='SGD', m=0.9, policy='poly', lr_power=0.9, lr_step=15, lr_factor=0.1, Adam_p=None, test=True, warmup=0, train_display_interval=1, valid_interval=10, n_final_epochs=5, save_best_model=True, style_transfer=True, L=0.0001, num_images_per_style=-1)
# Downloading: "https://github.com/d-li14/mobilenetv2.pytorch/raw/master/pretrained/mobilenetv2_1.0-0c6065bc.pth" to /root/.cache/torch/hub/checkpoints/mobilenetv2_1.0-0c6065bc.pth
# 100%|██████████| 13.5M/13.5M [00:00<00:00, 293MB/s]
#  Generating datasets...
#  ...done
#  Creating the styles
# ...
# 100%|██████████| 25/25 [00:04<00:00,  5.51it/s]
#  Finished!
#
#
#  Epoch 1/100
#  Time for train loop: 227.08 seconds
#
#  Train results for current epoch:
# 	 loss:  1.005137066687307
# ...

# %%
args_dict = {
    'seed' : 42,
    'dataset' : 'gtaV',
    'model' : 'deeplabv3_mobilenetv2',
    'num_epochs' : 100,
    'n_exp' : 28,
    'print_times' : True,
    'da' : 'advanced',
    'bs' : 8,
    'nw' : 2,
    'lr': 0.01,
    'wd' : 0.00001,
    'hnm' : False,
    'opt' : 'SGD',
    'm' : 0.9,
    'policy' : 'poly',
    'test' : True,
    'warmup' : 0,
    'train_display_interval' : 1,
    'valid_interval' :  10,
    'n_final_epochs' :  5,
    'save_best_model' : True,
    'style_transfer' : True,
    'L' : 0.0001,
    'num_images_per_style' : 5
}

experiment_t3(args_dict)

# !cp -r "/content/Results/Best_Models/T3/"* "/content/drive/MyDrive/MLDL-Project/Code/Codebase_inUse/Results/Best_Models/T3/"
# !cp -r "/content/Results/Plots/Plots_T3/"* "/content/drive/MyDrive/MLDL-Project/Code/Codebase_inUse/Results/Plots/Plots_T3/"
# Out:
#
#
#  #############################################
#
#  I'm in the experiment:
#   Namespace(seed=42, dataset='gtaV', model='deeplabv3_mobilenetv2', num_epochs=100, n_exp=28, print_times=True, da='advanced', bs=8, nw=2, lr=0.01, wd=1e-05, hnm=False, opt='SGD', m=0.9, policy='poly', lr_power=0.9, lr_step=15, lr_factor=0.1, Adam_p=None, test=True, warmup=0, train_display_interval=1, valid_interval=10, n_final_epochs=5, save_best_model=True, style_transfer=True, L=0.0001, num_images_per_style=5)
# Downloading: "https://github.com/d-li14/mobilenetv2.pytorch/raw/master/pretrained/mobilenetv2_1.0-0c6065bc.pth" to /root/.cache/torch/hub/checkpoints/mobilenetv2_1.0-0c6065bc.pth
# 100%|██████████| 13.5M/13.5M [00:00<00:00, 221MB/s]
#  Generating datasets...
#  ...done
#  Creating the styles
# ...
# 100%|██████████| 5/5 [00:01<00:00,  4.41it/s]
#  Finished!
#
#
#  Epoch 1/100
#  Time for train loop: 236.34 seconds
#
#  Train results for current epoch:
# 	 loss:  1.0003039649417322
# ...

# %%
####CHECKING THE SHORT BETA

args_dict = {
    'seed' : 42,
    'dataset' : 'gtaV',
    'model' : 'deeplabv3_mobilenetv2',
    'num_epochs' : 20,
    'n_exp' : 29,
    'print_times' : True,
    'da' : 'advanced',
    'bs' : 8,
    'nw' : 2,
    'lr': 0.01,
    'wd' : 0.00001,
    'hnm' : False,
    'opt' : 'SGD',
    'm' : 0.9,
    'policy' : 'poly',
    'test' : True,
    'warmup' : 0,
    'train_display_interval' : 1,
    'valid_interval' :  2,
    'n_final_epochs' :  2,
    'save_best_model' : True,
    'style_transfer' : True,
    'L' : 0.0001,
    'num_images_per_style' : 5
}

experiment_t3(args_dict)

# !cp -r "/content/Results/Best_Models/T3/"* "/content/drive/MyDrive/MLDL-Project/Code/Codebase_inUse/Results/Best_Models/T3/"
# !cp -r "/content/Results/Plots/Plots_T3/"* "/content/drive/MyDrive/MLDL-Project/Code/Codebase_inUse/Results/Plots/Plots_T3/"
# Out:
#
#
#  #############################################
#
#  I'm in the experiment:
#   Namespace(seed=42, dataset='gtaV', model='deeplabv3_mobilenetv2', num_epochs=20, n_exp=29, print_times=True, da='advanced', bs=8, nw=2, lr=0.01, wd=1e-05, hnm=False, opt='SGD', m=0.9, policy='poly', lr_power=0.9, lr_step=15, lr_factor=0.1, Adam_p=None, test=True, warmup=0, train_display_interval=1, valid_interval=2, n_final_epochs=2, save_best_model=True, style_transfer=True, L=0.0001, num_images_per_style=5)
#  Generating datasets...
#  ...done
#  Creating the styles
# ...
# 100%|██████████| 5/5 [00:00<00:00,  5.94it/s]
#  Finished!
#
#
#  Epoch 1/20
#  Time for train loop: 226.99 seconds
#
#  Train results for current epoch:
# 	 loss:  1.0041978887973293
# 	 mIoU:  0.19188003270888815
# 	 fwIoU:  0.5416352327714955
# 	 pAcc:  0.2449194020154271
#
#
#  Epoch 2/20
#
#  Time for train loop: 225.57 seconds
#
#  Train results for current epoch:
# 	 loss:  0.5756729379776986
# 	 mIoU:  0.2614913491722464
# ...

# %%
####CHECKING THE SHORT BETA

args_dict = {
    'seed' : 42,
    'dataset' : 'gtaV',
    'model' : 'deeplabv3_mobilenetv2',
    'num_epochs' : 20,
    'n_exp' : 30,
    'print_times' : True,
    'da' : 'advanced',
    'bs' : 8,
    'nw' : 2,
    'lr': 0.01,
    'wd' : 0.00001,
    'hnm' : False,
    'opt' : 'SGD',
    'm' : 0.9,
    'policy' : 'poly',
    'test' : True,
    'warmup' : 0,
    'train_display_interval' : 1,
    'valid_interval' :  2,
    'n_final_epochs' :  2,
    'save_best_model' : True,
    'style_transfer' : True,
    'L' : 0.0001,
    'num_images_per_style' : 5
}

experiment_t3(args_dict)

#!cp -r "/content/Results/Best_Models/T3/"* "/content/drive/MyDrive/MLDL-Project/Code/Codebase_inUse/Results/Best_Models/T3/"
#!cp -r "/content/Results/Plots/Plots_T3/"* "/content/drive/MyDrive/MLDL-Project/Code/Codebase_inUse/Results/Plots/Plots_T3/"
# Out:
#
#
#  #############################################
#
#  I'm in the experiment:
#   Namespace(seed=42, dataset='gtaV', model='deeplabv3_mobilenetv2', num_epochs=20, n_exp=30, print_times=True, da='advanced', bs=8, nw=2, lr=0.01, wd=1e-05, hnm=False, opt='SGD', m=0.9, policy='poly', lr_power=0.9, lr_step=15, lr_factor=0.1, Adam_p=None, test=True, warmup=0, train_display_interval=1, valid_interval=2, n_final_epochs=2, save_best_model=True, style_transfer=True, L=0.0001, num_images_per_style=5)
# Downloading: "https://github.com/d-li14/mobilenetv2.pytorch/raw/master/pretrained/mobilenetv2_1.0-0c6065bc.pth" to /root/.cache/torch/hub/checkpoints/mobilenetv2_1.0-0c6065bc.pth
# 100%|██████████| 13.5M/13.5M [00:00<00:00, 229MB/s]
#  Generating datasets...
#  ...done
#  Creating the styles
# ...
# 100%|██████████| 5/5 [00:10<00:00,  2.15s/it]
#  Finished!
#
#
#  Epoch 1/20
#  Time for train loop: 600.53 seconds
#
#  Train results for current epoch:
# 	 loss:  1.0015464896155941
# ...

# %% [markdown]
# # 3.2, Long again (but with 100)

# %% [markdown]
# Retrain 3.2 with a comparable number of epochs

# %%
args_dict = {
    'seed' : 42,
    'dataset' : 'gtaV',
    'model' : 'deeplabv3_mobilenetv2',
    'num_epochs' : 100 ,
    'n_exp' : 25,
    'print_times' : True,
    'da' : 'advanced',
    'bs' : 8,
    'nw' : 2,
    'lr': 0.1,
    'wd' : 0.00001,
    'hnm' : False,
    'opt' : 'SGD',
    'm' : 0.9,
    'policy' : 'poly',
    'lr_power' : 0.9,
    'test' : True,
    'warmup' : 0,
    'train_display_interval' : 5,
    'valid_interval' :  10,
    'n_final_epochs' :  10,
    'save_best_model' : True,
    'style_transfer' : False,
    'L' : 0.01,
    'num_images_per_style' : -1
}

experiment_t3(args_dict)
# Out:
#
#
#  #############################################
#
#  I'm in the experiment:
#   Namespace(seed=42, dataset='gtaV', model='deeplabv3_mobilenetv2', num_epochs=100, n_exp=25, print_times=True, da='advanced', bs=8, nw=2, lr=0.1, wd=1e-05, hnm=False, opt='SGD', m=0.9, policy='poly', lr_power=0.9, lr_step=15, lr_factor=0.1, Adam_p=None, test=True, warmup=0, train_display_interval=5, valid_interval=10, n_final_epochs=10, save_best_model=True, style_transfer=False, L=0.01, num_images_per_style=-1)
# Downloading: "https://github.com/d-li14/mobilenetv2.pytorch/raw/master/pretrained/mobilenetv2_1.0-0c6065bc.pth" to /root/.cache/torch/hub/checkpoints/mobilenetv2_1.0-0c6065bc.pth
# 100%|██████████| 13.5M/13.5M [00:00<00:00, 180MB/s]
#  Generating datasets...
#  ...done
#
#
#  Epoch 1/100
#
#  Time for train loop: 244.78 seconds
#
#
#  Epoch 2/100
#
#  Time for train loop: 66.98 seconds
#
#
#  Epoch 3/100
#
#  Time for train loop: 66.91 seconds
#
#
#  Epoch 4/100
#
# ...

# %%
args_dict = {
    'seed' : 42,
    'dataset' : 'gtaV',
    'model' : 'deeplabv3_mobilenetv2',
    'num_epochs' : 100 ,
    'n_exp' : 26,
    'print_times' : True,
    'da' : 'advanced',
    'bs' : 8,
    'nw' : 2,
    'lr': 0.01,
    'wd' : 0.00001,
    'hnm' : False,
    'opt' : 'SGD',
    'm' : 0.9,
    'policy' : 'poly',
    'lr_power' : 0.9,
    'test' : True,
    'warmup' : 0,
    'train_display_interval' : 5,
    'valid_interval' :  10,
    'n_final_epochs' :  10,
    'save_best_model' : True,
    'style_transfer' : False,
    'L' : 0.01,
    'num_images_per_style' : -1
}

experiment_t3(args_dict)
# Out:
#
#
#  #############################################
#
#  I'm in the experiment:
#   Namespace(seed=42, dataset='gtaV', model='deeplabv3_mobilenetv2', num_epochs=100, n_exp=26, print_times=True, da='advanced', bs=8, nw=2, lr=0.01, wd=1e-05, hnm=False, opt='SGD', m=0.9, policy='poly', lr_power=0.9, lr_step=15, lr_factor=0.1, Adam_p=None, test=True, warmup=0, train_display_interval=5, valid_interval=10, n_final_epochs=10, save_best_model=True, style_transfer=False, L=0.01, num_images_per_style=-1)
# Downloading: "https://github.com/d-li14/mobilenetv2.pytorch/raw/master/pretrained/mobilenetv2_1.0-0c6065bc.pth" to /root/.cache/torch/hub/checkpoints/mobilenetv2_1.0-0c6065bc.pth
# 100%|██████████| 13.5M/13.5M [00:00<00:00, 118MB/s]
#  Generating datasets...
#  ...done
#
#
#  Epoch 1/100
#
#  Time for train loop: 195.19 seconds
#
#
#  Epoch 2/100
#
#  Time for train loop: 70.76 seconds
#
#
#  Epoch 3/100
#
#  Time for train loop: 72.34 seconds
#
#
#  Epoch 4/100
#
# ...

# %% [markdown]
# #EXTRA

# %%
# !cp -r "/content/drive/MyDrive/MLDL-Project/Code/Codebase_inUse/data" "/content/"
# %cd "/content/"

args_dict = {
    'seed' : 42,
    'dataset' : 'gtaV',
    'model' : 'deeplabv3_mobilenetv2',
    'num_epochs' : 30,
    'n_exp' : 88,
    'print_times' : True,
    'da' : 'advanced',
    'bs' : 8,
    'nw' : 2,
    'lr': 0.01,
    'wd' : 0.00001,
    'hnm' : False,
    'opt' : 'SGD',
    'm' : 0.9,
    'policy' : 'poly',
    'test' : True,
    'warmup' : 0,
    'train_display_interval' : 1,
    'valid_interval' :  5,
    'n_final_epochs' :  3,
    'save_best_model' : True,
    'style_transfer' : True,
    'L' : 0.000001,
    'num_images_per_style' : 5
}

experiment_t3(args_dict)
# Out:
# /content
#
#
#  #############################################
#
#  I'm in the experiment:
#   Namespace(seed=42, dataset='gtaV', model='deeplabv3_mobilenetv2', num_epochs=30, n_exp=88, print_times=True, da='advanced', bs=8, nw=2, lr=0.01, wd=1e-05, hnm=False, opt='SGD', m=0.9, policy='poly', lr_power=0.9, lr_step=15, lr_factor=0.1, Adam_p=None, test=True, warmup=0, train_display_interval=1, valid_interval=5, n_final_epochs=3, save_best_model=True, style_transfer=True, L=1e-06, num_images_per_style=5)
#  Generating datasets...
#  ...done
#  Creating the styles
# ...
# 100%|██████████| 5/5 [00:01<00:00,  4.00it/s]
#  Finished!
#
#
#  Epoch 1/30
#  Time for train loop: 237.06 seconds
#
#  Train results for current epoch:
# 	 loss:  0.9995732994810227
# 	 mIoU:  0.1931557994137504
# 	 fwIoU:  0.5445735368243919
# 	 pAcc:  0.24612413348809234
#
#
#  Epoch 2/30
#
#  Time for train loop: 229.67 seconds
#
#  Train results for current epoch:
# 	 loss:  0.5682460444588815
# ...
