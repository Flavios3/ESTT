# %% [markdown]
# What we did in OLD:
# - 5 epochs to test lr,wd, SDG, ADAM
#   - no DA
#   - no scheduler
# - best models of previous step with 20 epochs, no difference in config
# - best models with scheduler (50? epochs)
#   - insert DA
#   - insert scheduler
# - train to the end the best model (8h)

# %%
#Mounting the drive
#import os
#import sys

from google.colab import drive
drive.mount('/content/drive')
# %cd "/content/drive/MyDrive/MLDL-Project/Code/Codebase_inUse"
#sys.path.append(os.path.abspath('Code/Codebase_inUse'))
# Out:
# Mounted at /content/drive
# /content/drive/.shortcut-targets-by-id/1qdeOmMzRTTZYag_nMfIYW1ptaZ_OpJwD/MLDL-Project/Code/Codebase_inUse

# %%
from model_t1 import *

# %% [markdown]
# # 1 - Coarse Grid Search
#
# Train several models under different configurations for a very small number of epochs, to get a feeling of the problem.
# In particular
# - train for 5 epochs
# - a configuration is a couple (lr, wd); standard values are considered as possible for those param.s (for a total of 12 configurations)
# - no scheduler is used yet

# %% [markdown]
# ### A - SGD

# %%
# Experiments with SGD

args_dict = {
    #arguments for the experimental setup
    'seed' : 42,
    'dataset' : 'idda',
    'model' : 'deeplabv3_mobilenetv2',
    'num_epochs' : 5,
    'n_exp' : 1,
    'print_times' : True,
    #arguments for the model parameters
    'da' : 'basic',
    'bs' : 8,
    'nw' : 2,
    'lr': 0.1,
    'wd' : 0.0001,
    #arguments for the optimizer and scheduler
    'opt' : 'SGD',
    'm' : 0.9,
    'policy' : 'None',
    #arguments for the handling of validation and testing
    'test' : False,
    'warmup' : 0,
    'train_display_interval' : 1,
    'valid_interval' : 1,
    'n_final_epochs' : 5,
    'save_best_model' : False
}

experiment_t1(args_dict)
# Out:
#
#
#  #############################################
#
#  I'm in the experiment:
#   Namespace(seed=42, dataset='idda', model='deeplabv3_mobilenetv2', num_epochs=5, n_exp=1, print_times=True, da='basic', bs=8, nw=2, lr=0.1, wd=0.0001, hnm=None, opt='SGD', m=0.9, policy='None', lr_power=0.9, lr_step=15, lr_factor=0.1, Adam_p=None, test=False, warmup=0, train_display_interval=1, valid_interval=1, n_final_epochs=5, save_best_model=False)
#  Generating datasets...
#  ...done
#  Splitting the training set...
#  ...done
#
#
#  Epoch 1/5
#
#  Time for train loop: 57.43 seconds
#
#  Train results for current epoch:
# 	 loss:  [0.5592970828215281]
# 	 mIoU:  [0.2651470944454792]
# 	 fwIoU:  [0.7262045835370553]
# 	 pAcc:  [0.3137526540242132]
#
#  Validation results:
# 	 - loss=0.38389166990915935
# 	 - mIoU=0.29727613620355
# 	 - fwIoU=0.7903166092601386
# 	 - pAcc=0.3461185744930078
#
#  Time for eval loop: 11.58 seconds
#
#
#  Epoch 2/5
#
#  Time for train loop: 54.15 seconds
#
# ...

# %%
args_dict['wd'] = 0.00001
args_dict['n_exp'] = 2
args_dict['print_times'] = False
experiment_t1(args_dict)
# Out:
#
#
#  #############################################
#
#  I'm in the experiment:
#   Namespace(seed=42, dataset='idda', model='deeplabv3_mobilenetv2', num_epochs=5, n_exp=2, print_times=False, da='basic', bs=8, nw=2, lr=0.1, wd=1e-05, hnm=None, opt='SGD', m=0.9, policy='None', lr_power=0.9, lr_step=15, lr_factor=0.1, Adam_p=None, test=False, warmup=0, train_display_interval=1, valid_interval=1, n_final_epochs=5, save_best_model=False)
#  Generating datasets...
#  ...done
#  Splitting the training set...
#  ...done
#
#
#  Epoch 1/5
#
#  Train results for current epoch:
# 	 loss:  [0.5661216308673223]
# 	 mIoU:  [0.26202333809746164]
# 	 fwIoU:  [0.7223505896774571]
# 	 pAcc:  [0.3107397841253716]
#
#  Validation results:
# 	 - loss=0.3821795960267385
# 	 - mIoU=0.29690059050269746
# 	 - fwIoU=0.7910974331864982
# 	 - pAcc=0.3477444904916449
#
#
#  Epoch 2/5
#
#  Train results for current epoch:
# 	 loss:  [0.5661216308673223, 0.3340322010219097]
# ...

# %%
args_dict['wd'] = 0
args_dict['n_exp'] = 3
experiment_t1(args_dict)
# Out:
#
#
#  #############################################
#
#  I'm in the experiment:
#   Namespace(seed=42, dataset='idda', model='deeplabv3_mobilenetv2', num_epochs=5, n_exp=3, print_times=False, da='basic', bs=8, nw=2, lr=0.1, wd=0, hnm=None, opt='SGD', m=0.9, policy='None', lr_power=0.9, lr_step=15, lr_factor=0.1, Adam_p=None, test=False, warmup=0, train_display_interval=1, valid_interval=1, n_final_epochs=5, save_best_model=False)
#  Generating datasets...
#  ...done
#  Splitting the training set...
#  ...done
#
#
#  Epoch 1/5
#
#  Train results for current epoch:
# 	 loss:  [0.5811215952038765]
# 	 mIoU:  [0.25798277257830005]
# 	 fwIoU:  [0.7164857313327723]
# 	 pAcc:  [0.3074286274302593]
#
#  Validation results:
# 	 - loss=0.4309059679508209
# 	 - mIoU=0.28647881568831807
# 	 - fwIoU=0.7713365207217163
# 	 - pAcc=0.33906371936519
#
#
#  Epoch 2/5
#
#  Train results for current epoch:
# 	 loss:  [0.5811215952038765, 0.3422767753402392]
# ...

# %%
args_dict['lr'] = 0.01
args_dict['wd'] = 0.0001
args_dict['n_exp'] = 4
experiment_t1(args_dict)
# Out:
#
#
#  #############################################
#
#  I'm in the experiment:
#   Namespace(seed=42, dataset='idda', model='deeplabv3_mobilenetv2', num_epochs=5, n_exp=4, print_times=False, da='basic', bs=8, nw=2, lr=0.01, wd=0.0001, hnm=None, opt='SGD', m=0.9, policy='None', lr_power=0.9, lr_step=15, lr_factor=0.1, Adam_p=None, test=False, warmup=0, train_display_interval=1, valid_interval=1, n_final_epochs=5, save_best_model=False)
#  Generating datasets...
#  ...done
#  Splitting the training set...
#  ...done
#
#
#  Epoch 1/5
#
#  Train results for current epoch:
# 	 loss:  [0.7765471289555231]
# 	 mIoU:  [0.2305415617152553]
# 	 fwIoU:  [0.6537446830966802]
# 	 pAcc:  [0.277367727049684]
#
#  Validation results:
# 	 - loss=0.41858843962351483
# 	 - mIoU=0.28490584882349457
# 	 - fwIoU=0.7754537157375061
# 	 - pAcc=0.33448229292092846
#
#
#  Epoch 2/5
#
#  Train results for current epoch:
# 	 loss:  [0.7765471289555231, 0.36862839659055074]
# ...

# %%
args_dict['wd'] = 0.00001
args_dict['n_exp'] = 5
experiment_t1(args_dict)
# Out:
#
#
#  #############################################
#
#  I'm in the experiment:
#   Namespace(seed=42, dataset='idda', model='deeplabv3_mobilenetv2', num_epochs=5, n_exp=5, print_times=False, da='basic', bs=8, nw=2, lr=0.01, wd=1e-05, hnm=None, opt='SGD', m=0.9, policy='None', lr_power=0.9, lr_step=15, lr_factor=0.1, Adam_p=None, test=False, warmup=0, train_display_interval=1, valid_interval=1, n_final_epochs=5, save_best_model=False)
#  Generating datasets...
#  ...done
#  Splitting the training set...
#  ...done
#
#
#  Epoch 1/5
#
#  Train results for current epoch:
# 	 loss:  [0.7772734507918357]
# 	 mIoU:  [0.23032394524126742]
# 	 fwIoU:  [0.6533019385402588]
# 	 pAcc:  [0.2771860794452341]
#
#  Validation results:
# 	 - loss=0.4190337459246318
# 	 - mIoU=0.28423767215966694
# 	 - fwIoU=0.7739000301710812
# 	 - pAcc=0.33329935801391475
#
#
#  Epoch 2/5
#
#  Train results for current epoch:
# 	 loss:  [0.7772734507918357, 0.36803098271290463]
# ...

# %%
args_dict['wd'] = 0
args_dict['n_exp'] = 6
experiment_t1(args_dict)
# Out:
#
#
#  #############################################
#
#  I'm in the experiment:
#   Namespace(seed=42, dataset='idda', model='deeplabv3_mobilenetv2', num_epochs=5, n_exp=6, print_times=False, da='basic', bs=8, nw=2, lr=0.01, wd=0, hnm=None, opt='SGD', m=0.9, policy='None', lr_power=0.9, lr_step=15, lr_factor=0.1, Adam_p=None, test=False, warmup=0, train_display_interval=1, valid_interval=1, n_final_epochs=5, save_best_model=False)
#  Generating datasets...
#  ...done
#  Splitting the training set...
#  ...done
#
#
#  Epoch 1/5
#
#  Train results for current epoch:
# 	 loss:  [0.7770373637477557]
# 	 mIoU:  [0.23040513436703702]
# 	 fwIoU:  [0.653483934630607]
# 	 pAcc:  [0.2772683689732311]
#
#  Validation results:
# 	 - loss=0.42038909196853635
# 	 - mIoU=0.28508396302906297
# 	 - fwIoU=0.7751285116932176
# 	 - pAcc=0.3351206116331011
#
#
#  Epoch 2/5
#
#  Train results for current epoch:
# 	 loss:  [0.7770373637477557, 0.3681595101952553]
# ...

# %%
args_dict['lr'] = 0.001
args_dict['wd'] = 0.0001
args_dict['n_exp'] = 7
experiment_t1(args_dict)
# Out:
#
#
#  #############################################
#
#  I'm in the experiment:
#   Namespace(seed=42, dataset='idda', model='deeplabv3_mobilenetv2', num_epochs=5, n_exp=7, print_times=False, da='basic', bs=8, nw=2, lr=0.001, wd=0.0001, hnm=None, opt='SGD', m=0.9, policy='None', lr_power=0.9, lr_step=15, lr_factor=0.1, Adam_p=None, test=False, warmup=0, train_display_interval=1, valid_interval=1, n_final_epochs=5, save_best_model=False)
#  Generating datasets...
#  ...done
#  Splitting the training set...
#  ...done
#
#
#  Epoch 1/5
#
#  Train results for current epoch:
# 	 loss:  [1.5772977262735366]
# 	 mIoU:  [0.13069662016422043]
# 	 fwIoU:  [0.44120019849210934]
# 	 pAcc:  [0.17539979010539034]
#
#  Validation results:
# 	 - loss=0.8142998655637105
# 	 - mIoU=0.21813736002108297
# 	 - fwIoU=0.6430198882835795
# 	 - pAcc=0.26795409943327514
#
#
#  Epoch 2/5
#
#  Train results for current epoch:
# 	 loss:  [1.5772977262735366, 0.6544867709279061]
# ...

# %%
args_dict['wd'] = 0.00001
args_dict['n_exp'] = 8
experiment_t1(args_dict)
# Out:
#
#
#  #############################################
#
#  I'm in the experiment:
#   Namespace(seed=42, dataset='idda', model='deeplabv3_mobilenetv2', num_epochs=5, n_exp=8, print_times=False, da='basic', bs=8, nw=2, lr=0.001, wd=1e-05, hnm=None, opt='SGD', m=0.9, policy='None', lr_power=0.9, lr_step=15, lr_factor=0.1, Adam_p=None, test=False, warmup=0, train_display_interval=1, valid_interval=1, n_final_epochs=5, save_best_model=False)
#  Generating datasets...
#  ...done
#  Splitting the training set...
#  ...done
#
#
#  Epoch 1/5
#
#  Train results for current epoch:
# 	 loss:  [1.5773122658332188]
# 	 mIoU:  [0.13069072670023169]
# 	 fwIoU:  [0.44118968623635585]
# 	 pAcc:  [0.17539508423439543]
#
#  Validation results:
# 	 - loss=0.8144315679868063
# 	 - mIoU=0.21809103226814863
# 	 - fwIoU=0.6428874609846906
# 	 - pAcc=0.26790939562518734
#
#
#  Epoch 2/5
#
#  Train results for current epoch:
# 	 loss:  [1.5773122658332188, 0.6545067598422368]
# ...

# %%
args_dict['wd'] = 0
args_dict['n_exp'] = 9
experiment_t1(args_dict)
# Out:
#
#
#  #############################################
#
#  I'm in the experiment:
#   Namespace(seed=42, dataset='idda', model='deeplabv3_mobilenetv2', num_epochs=5, n_exp=9, print_times=False, da='basic', bs=8, nw=2, lr=0.001, wd=0, hnm=None, opt='SGD', m=0.9, policy='None', lr_power=0.9, lr_step=15, lr_factor=0.1, Adam_p=None, test=False, warmup=0, train_display_interval=1, valid_interval=1, n_final_epochs=5, save_best_model=False)
#  Generating datasets...
#  ...done
#  Splitting the training set...
#  ...done
#
#
#  Epoch 1/5
#
#  Train results for current epoch:
# 	 loss:  [1.5772362500429153]
# 	 mIoU:  [0.13071089889562287]
# 	 fwIoU:  [0.44122626349232597]
# 	 pAcc:  [0.17541826238302824]
#
#  Validation results:
# 	 - loss=0.8143913865089416
# 	 - mIoU=0.21814119412409275
# 	 - fwIoU=0.6429730903675386
# 	 - pAcc=0.2679598556355483
#
#
#  Epoch 2/5
#
#  Train results for current epoch:
# 	 loss:  [1.5772362500429153, 0.654498931268851]
# ...

# %%
args_dict['lr'] = 0.0001
args_dict['wd'] = 0.0001
args_dict['n_exp'] = 10
experiment_t1(args_dict)
# Out:
#
#
#  #############################################
#
#  I'm in the experiment:
#   Namespace(seed=42, dataset='idda', model='deeplabv3_mobilenetv2', num_epochs=5, n_exp=10, print_times=False, da='basic', bs=8, nw=2, lr=0.0001, wd=0.0001, hnm=None, opt='SGD', m=0.9, policy='None', lr_power=0.9, lr_step=15, lr_factor=0.1, Adam_p=None, test=False, warmup=0, train_display_interval=1, valid_interval=1, n_final_epochs=5, save_best_model=False)
#  Generating datasets...
#  ...done
#  Splitting the training set...
#  ...done
#
#
#  Epoch 1/5
#
#  Train results for current epoch:
# 	 loss:  [2.6387428919474285]
# 	 mIoU:  [0.052417749664802185]
# 	 fwIoU:  [0.18526822024012712]
# 	 pAcc:  [0.11432286094239959]
#
#  Validation results:
# 	 - loss=2.3971930503845216
# 	 - mIoU=0.12543148608897123
# 	 - fwIoU=0.4254862341335812
# 	 - pAcc=0.1753141949871962
#
#
#  Epoch 2/5
#
#  Train results for current epoch:
# 	 loss:  [2.6387428919474285, 2.074436304966609]
# ...

# %%
args_dict['wd'] = 0.00001
args_dict['n_exp'] = 11
experiment_t1(args_dict)
# Out:
#
#
#  #############################################
#
#  I'm in the experiment:
#   Namespace(seed=42, dataset='idda', model='deeplabv3_mobilenetv2', num_epochs=5, n_exp=11, print_times=False, da='basic', bs=8, nw=2, lr=0.0001, wd=1e-05, hnm=None, opt='SGD', m=0.9, policy='None', lr_power=0.9, lr_step=15, lr_factor=0.1, Adam_p=None, test=False, warmup=0, train_display_interval=1, valid_interval=1, n_final_epochs=5, save_best_model=False)
#  Generating datasets...
#  ...done
#  Splitting the training set...
#  ...done
#
#
#  Epoch 1/5
#
#  Train results for current epoch:
# 	 loss:  [2.6387421607971193]
# 	 mIoU:  [0.05241782327946306]
# 	 fwIoU:  [0.18526832155932718]
# 	 pAcc:  [0.11432515427360897]
#
#  Validation results:
# 	 - loss=2.3971906820933024
# 	 - mIoU=0.12543256769156774
# 	 - fwIoU=0.4254822332729675
# 	 - pAcc=0.1753177227789231
#
#
#  Epoch 2/5
#
#  Train results for current epoch:
# 	 loss:  [2.6387421607971193, 2.074429366985957]
# ...

# %%
args_dict['wd'] = 0
args_dict['n_exp'] = 12
experiment_t1(args_dict)
# Out:
#
#
#  #############################################
#
#  I'm in the experiment:
#   Namespace(seed=42, dataset='idda', model='deeplabv3_mobilenetv2', num_epochs=5, n_exp=12, print_times=False, da='basic', bs=8, nw=2, lr=0.0001, wd=0, hnm=None, opt='SGD', m=0.9, policy='None', lr_power=0.9, lr_step=15, lr_factor=0.1, Adam_p=None, test=False, warmup=0, train_display_interval=1, valid_interval=1, n_final_epochs=5, save_best_model=False)
#  Generating datasets...
#  ...done
#  Splitting the training set...
#  ...done
#
#
#  Epoch 1/5
#
#  Train results for current epoch:
# 	 loss:  [2.6387402852376303]
# 	 mIoU:  [0.05241828705537989]
# 	 fwIoU:  [0.1852700075084173]
# 	 pAcc:  [0.11432507744664534]
#
#  Validation results:
# 	 - loss=2.3971904436747233
# 	 - mIoU=0.1254317561804685
# 	 - fwIoU=0.4254876886556698
# 	 - pAcc=0.17531159088012135
#
#
#  Epoch 2/5
#
#  Train results for current epoch:
# 	 loss:  [2.6387402852376303, 2.07442893187205]
# ...

# %% [markdown]
# ## B - ADAM

# %%
# Experiments with SGD
args_dict = {
    #arguments for the experimental setup
    'seed' : 42,
    'dataset' : 'idda',
    'model' : 'deeplabv3_mobilenetv2',
    'num_epochs' : 5,
    'n_exp' : 13,
    'print_times' : True,
    #arguments for the model parameters
    'da' : 'basic',
    'bs' : 8,
    'nw' : 2,
    'lr': 0.1,
    'wd' : 0.0001,
    #arguments for the optimizer and scheduler
    'opt' : 'Adam',
    'Adam_p' : 'dft',
    'policy' : 'None',
    #arguments for the handling of validation and testing
    'test' : False,
    'warmup' : 0,
    'train_display_interval' : 1,
    'valid_interval' : 1,
    'n_final_epochs' : 5,
    'save_best_model' : False
}

experiment_t1(args_dict)
# Out:
#
#
#  #############################################
#
#  I'm in the experiment:
#   Namespace(seed=42, dataset='idda', model='deeplabv3_mobilenetv2', num_epochs=5, n_exp=13, print_times=True, da='basic', bs=8, nw=2, lr=0.1, wd=0.0001, hnm=None, opt='Adam', m=0.9, policy='None', lr_power=0.9, lr_step=15, lr_factor=0.1, Adam_p='dft', test=False, warmup=0, train_display_interval=1, valid_interval=1, n_final_epochs=5, save_best_model=False)
#  Generating datasets...
#  ...done
#  Splitting the training set...
#  ...done
#
#
#  Epoch 1/5
#
#  Time for train loop: 53.86 seconds
#
#  Train results for current epoch:
# 	 loss:  [1.2082692404588065]
# 	 mIoU:  [0.1340365279214714]
# 	 fwIoU:  [0.45306029859160124]
# 	 pAcc:  [0.18246201361910885]
#
#  Validation results:
# 	 - loss=2.025925938288371
# 	 - mIoU=0.041527590851628646
# 	 - fwIoU=0.15849966170460567
# 	 - pAcc=0.1056729839045909
#
#  Time for eval loop: 9.45 seconds
#
#
#  Epoch 2/5
#
#  Time for train loop: 55.01 seconds
#
# ...

# %%
args_dict['wd'] = 0.00001
args_dict['n_exp'] = 14
args_dict['print_times'] = False

experiment_t1(args_dict)
# Out:
#
#
#  #############################################
#
#  I'm in the experiment:
#   Namespace(seed=42, dataset='idda', model='deeplabv3_mobilenetv2', num_epochs=5, n_exp=14, print_times=False, da='basic', bs=8, nw=2, lr=0.1, wd=1e-05, hnm=None, opt='Adam', m=0.9, policy='None', lr_power=0.9, lr_step=15, lr_factor=0.1, Adam_p='dft', test=False, warmup=0, train_display_interval=1, valid_interval=1, n_final_epochs=5, save_best_model=False)
#  Generating datasets...
#  ...done
#  Splitting the training set...
#  ...done
#
#
#  Epoch 1/5
#
#  Train results for current epoch:
# 	 loss:  [1.1459644426902136]
# 	 mIoU:  [0.13678922791896087]
# 	 fwIoU:  [0.46604011212870394]
# 	 pAcc:  [0.1850028253516973]
#
#  Validation results:
# 	 - loss=0.8172363201777141
# 	 - mIoU=0.16329836956980467
# 	 - fwIoU=0.5583057737919804
# 	 - pAcc=0.21744433571002836
#
#
#  Epoch 2/5
#
#  Train results for current epoch:
# 	 loss:  [1.1459644426902136, 0.7376247922579448]
# ...

# %%
args_dict['wd'] = 0
args_dict['n_exp'] = 15

experiment_t1(args_dict)
# Out:
#
#
#  #############################################
#
#  I'm in the experiment:
#   Namespace(seed=42, dataset='idda', model='deeplabv3_mobilenetv2', num_epochs=5, n_exp=15, print_times=False, da='basic', bs=8, nw=2, lr=0.1, wd=0, hnm=None, opt='Adam', m=0.9, policy='None', lr_power=0.9, lr_step=15, lr_factor=0.1, Adam_p='dft', test=False, warmup=0, train_display_interval=1, valid_interval=1, n_final_epochs=5, save_best_model=False)
#  Generating datasets...
#  ...done
#  Splitting the training set...
#  ...done
#
#
#  Epoch 1/5
#
#  Train results for current epoch:
# 	 loss:  [1.2212960402170816]
# 	 mIoU:  [0.13063359157060161]
# 	 fwIoU:  [0.44197618323781324]
# 	 pAcc:  [0.1778094028514552]
#
#  Validation results:
# 	 - loss=1.716079330444336
# 	 - mIoU=0.11648765024977793
# 	 - fwIoU=0.3968689741056187
# 	 - pAcc=0.16277681591696933
#
#
#  Epoch 2/5
#
#  Train results for current epoch:
# 	 loss:  [1.2212960402170816, 0.7214159915844599]
# ...

# %%
args_dict['lr'] = 0.01
args_dict['wd'] = 0.0001
args_dict['n_exp'] = 16

experiment_t1(args_dict)
# Out:
#
#
#  #############################################
#
#  I'm in the experiment:
#   Namespace(seed=42, dataset='idda', model='deeplabv3_mobilenetv2', num_epochs=5, n_exp=16, print_times=False, da='basic', bs=8, nw=2, lr=0.01, wd=0.0001, hnm=None, opt='Adam', m=0.9, policy='None', lr_power=0.9, lr_step=15, lr_factor=0.1, Adam_p='dft', test=False, warmup=0, train_display_interval=1, valid_interval=1, n_final_epochs=5, save_best_model=False)
#  Generating datasets...
#  ...done
#  Splitting the training set...
#  ...done
#
#
#  Epoch 1/5
#
#  Train results for current epoch:
# 	 loss:  [0.8468774904807409]
# 	 mIoU:  [0.19972770634724107]
# 	 fwIoU:  [0.5900543961506136]
# 	 pAcc:  [0.25354125132476496]
#
#  Validation results:
# 	 - loss=1.1746684392293294
# 	 - mIoU=0.14774268985224132
# 	 - fwIoU=0.416661762311022
# 	 - pAcc=0.2297417471922239
#
#
#  Epoch 2/5
#
#  Train results for current epoch:
# 	 loss:  [0.8468774904807409, 0.5082621157169342]
# ...

# %%
args_dict['wd'] = 0.00001
args_dict['n_exp'] = 17

experiment_t1(args_dict)
# Out:
#
#
#  #############################################
#
#  I'm in the experiment:
#   Namespace(seed=42, dataset='idda', model='deeplabv3_mobilenetv2', num_epochs=5, n_exp=17, print_times=False, da='basic', bs=8, nw=2, lr=0.01, wd=1e-05, hnm=None, opt='Adam', m=0.9, policy='None', lr_power=0.9, lr_step=15, lr_factor=0.1, Adam_p='dft', test=False, warmup=0, train_display_interval=1, valid_interval=1, n_final_epochs=5, save_best_model=False)
#  Generating datasets...
#  ...done
#  Splitting the training set...
#  ...done
#
#
#  Epoch 1/5
#
#  Train results for current epoch:
# 	 loss:  [0.8392776216069857]
# 	 mIoU:  [0.1979468714148123]
# 	 fwIoU:  [0.5905767670398839]
# 	 pAcc:  [0.2513062931559517]
#
#  Validation results:
# 	 - loss=1.2612034519513449
# 	 - mIoU=0.15558187296701934
# 	 - fwIoU=0.515154639714911
# 	 - pAcc=0.21603445479547662
#
#
#  Epoch 2/5
#
#  Train results for current epoch:
# 	 loss:  [0.8392776216069857, 0.4993914797902107]
# ...

# %%
args_dict['wd'] = 0
args_dict['n_exp'] = 18

experiment_t1(args_dict)
# Out:
#
#
#  #############################################
#
#  I'm in the experiment:
#   Namespace(seed=42, dataset='idda', model='deeplabv3_mobilenetv2', num_epochs=5, n_exp=18, print_times=False, da='basic', bs=8, nw=2, lr=0.01, wd=0, hnm=None, opt='Adam', m=0.9, policy='None', lr_power=0.9, lr_step=15, lr_factor=0.1, Adam_p='dft', test=False, warmup=0, train_display_interval=1, valid_interval=1, n_final_epochs=5, save_best_model=False)
#  Generating datasets...
#  ...done
#  Splitting the training set...
#  ...done
#
#
#  Epoch 1/5
#
#  Train results for current epoch:
# 	 loss:  [0.8373233412702878]
# 	 mIoU:  [0.20136215801098264]
# 	 fwIoU:  [0.5938883894324031]
# 	 pAcc:  [0.2550800614575392]
#
#  Validation results:
# 	 - loss=0.6974362373352051
# 	 - mIoU=0.21723086498571814
# 	 - fwIoU=0.6457098172118942
# 	 - pAcc=0.27600627764546826
#
#
#  Epoch 2/5
#
#  Train results for current epoch:
# 	 loss:  [0.8373233412702878, 0.4812452673912048]
# ...

# %%
args_dict['lr'] = 0.001
args_dict['wd'] = 0.0001
args_dict['n_exp'] = 19

experiment_t1(args_dict)
# Out:
#
#
#  #############################################
#
#  I'm in the experiment:
#   Namespace(seed=42, dataset='idda', model='deeplabv3_mobilenetv2', num_epochs=5, n_exp=19, print_times=False, da='basic', bs=8, nw=2, lr=0.001, wd=0.0001, hnm=None, opt='Adam', m=0.9, policy='None', lr_power=0.9, lr_step=15, lr_factor=0.1, Adam_p='dft', test=False, warmup=0, train_display_interval=1, valid_interval=1, n_final_epochs=5, save_best_model=False)
#  Generating datasets...
#  ...done
#  Splitting the training set...
#  ...done
#
#
#  Epoch 1/5
#
#  Train results for current epoch:
# 	 loss:  [0.5395217686891556]
# 	 mIoU:  [0.27248450609216884]
# 	 fwIoU:  [0.7479544972530037]
# 	 pAcc:  [0.3183607711696106]
#
#  Validation results:
# 	 - loss=0.36256120204925535
# 	 - mIoU=0.299985627644878
# 	 - fwIoU=0.79863039877629
# 	 - pAcc=0.3427745229057567
#
#
#  Epoch 2/5
#
#  Train results for current epoch:
# 	 loss:  [0.5395217686891556, 0.32110873982310295]
# ...

# %%
args_dict['wd'] = 0.00001
args_dict['n_exp'] = 20

experiment_t1(args_dict)
# Out:
#
#
#  #############################################
#
#  I'm in the experiment:
#   Namespace(seed=42, dataset='idda', model='deeplabv3_mobilenetv2', num_epochs=5, n_exp=20, print_times=False, da='basic', bs=8, nw=2, lr=0.001, wd=1e-05, hnm=None, opt='Adam', m=0.9, policy='None', lr_power=0.9, lr_step=15, lr_factor=0.1, Adam_p='dft', test=False, warmup=0, train_display_interval=1, valid_interval=1, n_final_epochs=5, save_best_model=False)
#  Generating datasets...
#  ...done
#  Splitting the training set...
#  ...done
#
#
#  Epoch 1/5
#
#  Train results for current epoch:
# 	 loss:  [0.5381847570339838]
# 	 mIoU:  [0.27279907297357514]
# 	 fwIoU:  [0.7486844062641863]
# 	 pAcc:  [0.3185935175870668]
#
#  Validation results:
# 	 - loss=0.3571770270665487
# 	 - mIoU=0.30115258299571585
# 	 - fwIoU=0.8008769553417296
# 	 - pAcc=0.34332878426950636
#
#
#  Epoch 2/5
#
#  Train results for current epoch:
# 	 loss:  [0.5381847570339838, 0.31864491999149325]
# ...

# %%
args_dict['wd'] = 0
args_dict['n_exp'] = 21

experiment_t1(args_dict)
# Out:
#
#
#  #############################################
#
#  I'm in the experiment:
#   Namespace(seed=42, dataset='idda', model='deeplabv3_mobilenetv2', num_epochs=5, n_exp=21, print_times=False, da='basic', bs=8, nw=2, lr=0.001, wd=0, hnm=None, opt='Adam', m=0.9, policy='None', lr_power=0.9, lr_step=15, lr_factor=0.1, Adam_p='dft', test=False, warmup=0, train_display_interval=1, valid_interval=1, n_final_epochs=5, save_best_model=False)
#  Generating datasets...
#  ...done
#  Splitting the training set...
#  ...done
#
#
#  Epoch 1/5
#
#  Train results for current epoch:
# 	 loss:  [0.5406753028432528]
# 	 mIoU:  [0.27210056803741156]
# 	 fwIoU:  [0.7474642247286174]
# 	 pAcc:  [0.31800614082640755]
#
#  Validation results:
# 	 - loss=0.3678349991639455
# 	 - mIoU=0.29842181420816644
# 	 - fwIoU=0.7946883587801015
# 	 - pAcc=0.34079968245356473
#
#
#  Epoch 2/5
#
#  Train results for current epoch:
# 	 loss:  [0.5406753028432528, 0.3236961337427298]
# ...

# %%
args_dict['lr'] = 0.0001
args_dict['wd'] = 0.0001
args_dict['n_exp'] = 22

experiment_t1(args_dict)
# Out:
#
#
#  #############################################
#
#  I'm in the experiment:
#   Namespace(seed=42, dataset='idda', model='deeplabv3_mobilenetv2', num_epochs=5, n_exp=22, print_times=False, da='basic', bs=8, nw=2, lr=0.0001, wd=0.0001, hnm=None, opt='Adam', m=0.9, policy='None', lr_power=0.9, lr_step=15, lr_factor=0.1, Adam_p='dft', test=False, warmup=0, train_display_interval=1, valid_interval=1, n_final_epochs=5, save_best_model=False)
#  Generating datasets...
#  ...done
#  Splitting the training set...
#  ...done
#
#
#  Epoch 1/5
#
#  Train results for current epoch:
# 	 loss:  [0.9319209709763527]
# 	 mIoU:  [0.2493984396479616]
# 	 fwIoU:  [0.699640505778794]
# 	 pAcc:  [0.2971661830281763]
#
#  Validation results:
# 	 - loss=0.5098999957243602
# 	 - mIoU=0.29003087724638626
# 	 - fwIoU=0.7856438020235781
# 	 - pAcc=0.33616272381658663
#
#
#  Epoch 2/5
#
#  Train results for current epoch:
# 	 loss:  [0.9319209709763527, 0.45695516616106036]
# ...

# %%
args_dict['wd'] = 0.00001
args_dict['n_exp'] = 23

experiment_t1(args_dict)
# Out:
#
#
#  #############################################
#
#  I'm in the experiment:
#   Namespace(seed=42, dataset='idda', model='deeplabv3_mobilenetv2', num_epochs=5, n_exp=23, print_times=False, da='basic', bs=8, nw=2, lr=0.0001, wd=1e-05, hnm=None, opt='Adam', m=0.9, policy='None', lr_power=0.9, lr_step=15, lr_factor=0.1, Adam_p='dft', test=False, warmup=0, train_display_interval=1, valid_interval=1, n_final_epochs=5, save_best_model=False)
#  Generating datasets...
#  ...done
#  Splitting the training set...
#  ...done
#
#
#  Epoch 1/5
#
#  Train results for current epoch:
# 	 loss:  [0.9318801656365394]
# 	 mIoU:  [0.24942374901668382]
# 	 fwIoU:  [0.6996709417003153]
# 	 pAcc:  [0.2972171135973627]
#
#  Validation results:
# 	 - loss=0.5093971868356069
# 	 - mIoU=0.29002589507646126
# 	 - fwIoU=0.7856008132504337
# 	 - pAcc=0.3362139106181945
#
#
#  Epoch 2/5
#
#  Train results for current epoch:
# 	 loss:  [0.9318801656365394, 0.4569388235608737]
# ...

# %%
args_dict['wd'] = 0
args_dict['n_exp'] = 24

experiment_t1(args_dict)
# Out:
#
#
#  #############################################
#
#  I'm in the experiment:
#   Namespace(seed=42, dataset='idda', model='deeplabv3_mobilenetv2', num_epochs=5, n_exp=24, print_times=False, da='basic', bs=8, nw=2, lr=0.0001, wd=0, hnm=None, opt='Adam', m=0.9, policy='None', lr_power=0.9, lr_step=15, lr_factor=0.1, Adam_p='dft', test=False, warmup=0, train_display_interval=1, valid_interval=1, n_final_epochs=5, save_best_model=False)
#  Generating datasets...
#  ...done
#  Splitting the training set...
#  ...done
#
#
#  Epoch 1/5
#
#  Train results for current epoch:
# 	 loss:  [0.9319027110934257]
# 	 mIoU:  [0.24941443695267645]
# 	 fwIoU:  [0.699658260254313]
# 	 pAcc:  [0.29720143199547766]
#
#  Validation results:
# 	 - loss=0.5093246261278789
# 	 - mIoU=0.29005425967529164
# 	 - fwIoU=0.7856480588600344
# 	 - pAcc=0.3362610724343593
#
#
#  Epoch 2/5
#
#  Train results for current epoch:
# 	 loss:  [0.9319027110934257, 0.4569152906537056]
# ...

# %% [markdown]
# # 2 - Best 2 models
#
# We know train the top 2 models (one with SGS and one with Adam) for 30 epochs each

# %%
args_dict = {
    #arguments for the experimental setup
    'seed' : 42,
    'dataset' : 'idda',
    'model' : 'deeplabv3_mobilenetv2',
    'num_epochs' : 30,
    'n_exp' : 25,
    'print_times' : False,
    #arguments for the model parameters
    'da' : 'advanced',
    'bs' : 8,
    'nw' : 2,
    'lr': 0.1,
    'wd' : 0.0001,
    #arguments for the optimizer and scheduler
    'opt' : 'SGD',
    'm' : 0.9,
    'policy' : 'None',
    #arguments for the handling of validation and testing
    'test' : False,
    'warmup' : 0,
    'train_display_interval' : 1,
    'valid_interval' : 1,
    'n_final_epochs' : 1,
    'save_best_model' : False
}

experiment_t1(args_dict)
# Out:
#
#
#  #############################################
#
#  I'm in the experiment:
#   Namespace(seed=42, dataset='idda', model='deeplabv3_mobilenetv2', num_epochs=30, n_exp=25, print_times=False, da='advanced', bs=8, nw=2, lr=0.1, wd=0.0001, hnm=None, opt='SGD', m=0.9, policy='None', lr_power=0.9, lr_step=15, lr_factor=0.1, Adam_p=None, test=False, warmup=0, train_display_interval=1, valid_interval=1, n_final_epochs=1, save_best_model=False)
# Downloading: "https://github.com/d-li14/mobilenetv2.pytorch/raw/master/pretrained/mobilenetv2_1.0-0c6065bc.pth" to /root/.cache/torch/hub/checkpoints/mobilenetv2_1.0-0c6065bc.pth
# 100%|██████████| 13.5M/13.5M [00:00<00:00, 195MB/s]
#  Generating datasets...
#  ...done
#  Splitting the training set...
#  ...done
#
#
#  Epoch 1/30
#
#  Train results for current epoch:
# 	 loss:  0.6323931033412615
# 	 mIoU:  0.24741508415219887
# 	 fwIoU:  0.6923402557696376
# 	 pAcc:  0.29844105231937723
#
#  Validation results:
# 	 - loss=0.924397345383962
# ...

# %%
args_dict = {
    #arguments for the experimental setup
    'seed' : 42,
    'dataset' : 'idda',
    'model' : 'deeplabv3_mobilenetv2',
    'num_epochs' : 30,
    'n_exp' : 26,
    'print_times' : False,
    #arguments for the model parameters
    'da' : 'advanced',
    'bs' : 8,
    'nw' : 2,
    'lr': 0.001,
    'wd' : 0.00001,
    #arguments for the optimizer and scheduler
    'opt' : 'Adam',
    'Adam_p' : 'dft',
    'policy' : 'None',
    #arguments for the handling of validation and testing
    'test' : False,
    'warmup' : 0,
    'train_display_interval' : 1,
    'valid_interval' : 1,
    'n_final_epochs' : 1,
    'save_best_model' : False
}

experiment_t1(args_dict)
# Out:
#
#
#  #############################################
#
#  I'm in the experiment:
#   Namespace(seed=42, dataset='idda', model='deeplabv3_mobilenetv2', num_epochs=30, n_exp=26, print_times=False, da='advanced', bs=8, nw=2, lr=0.001, wd=1e-05, hnm=None, opt='Adam', m=0.9, policy='None', lr_power=0.9, lr_step=15, lr_factor=0.1, Adam_p='dft', test=False, warmup=0, train_display_interval=1, valid_interval=1, n_final_epochs=1, save_best_model=False)
#  Generating datasets...
#  ...done
#  Splitting the training set...
#  ...done
#
#
#  Epoch 1/30
#
#  Train results for current epoch:
# 	 loss:  0.5556755582491557
# 	 mIoU:  0.26693338661195004
# 	 fwIoU:  0.7384627755158418
# 	 pAcc:  0.31387353443152305
#
#  Validation results:
# 	 - loss=0.3846748967965444
# 	 - mIoU=0.29321835329815205
# 	 - fwIoU=0.789352597897155
# 	 - pAcc=0.3392553374203428
#
#
#  Epoch 2/30
#
#  Train results for current epoch:
# 	 loss:  0.34361288597186407
# 	 mIoU:  0.31043457738597136
# ...

# %% [markdown]
# # 3 - LR decay
# We know try 2 types of decay:
# - step
# - poly (FedDrive)

# %%
args_dict = {
    #arguments for the experimental setup
    'seed' : 42,
    'dataset' : 'idda',
    'model' : 'deeplabv3_mobilenetv2',
    'num_epochs' : 50,
    'n_exp' : 27,
    'print_times' : False,
    #arguments for the model parameters
    'da' : 'advanced',
    'bs' : 8,
    'nw' : 2,
    'lr': 0.1,
    'wd' : 0.0001,
    #arguments for the optimizer and scheduler
    'opt' : 'SGD',
    'm' : 0.9,
    'policy' : 'poly',
    'lr_power' : 0.9,
    #arguments for the handling of validation and testing
    'test' : False,
    'warmup' : 0,
    'train_display_interval' : 1,
    'valid_interval' : 1,
    'n_final_epochs' : 5,
    'save_best_model' : False
}

experiment_t1(args_dict)
# Out:
#
#
#  #############################################
#
#  I'm in the experiment:
#   Namespace(seed=42, dataset='idda', model='deeplabv3_mobilenetv2', num_epochs=50, n_exp=27, print_times=False, da='advanced', bs=8, nw=2, lr=0.1, wd=0.0001, hnm=None, opt='SGD', m=0.9, policy='poly', lr_power=0.9, lr_step=15, lr_factor=0.1, Adam_p=None, test=False, warmup=0, train_display_interval=1, valid_interval=1, n_final_epochs=5, save_best_model=False)
# Downloading: "https://github.com/d-li14/mobilenetv2.pytorch/raw/master/pretrained/mobilenetv2_1.0-0c6065bc.pth" to /root/.cache/torch/hub/checkpoints/mobilenetv2_1.0-0c6065bc.pth
# 100%|██████████| 13.5M/13.5M [00:00<00:00, 225MB/s]
#  Generating datasets...
#  ...done
#  Splitting the training set...
#  ...done
#
#
#  Epoch 1/50
#
#  Train results for current epoch:
# 	 loss:  0.6098833218216896
# 	 mIoU:  0.25338678879907517
# 	 fwIoU:  0.703400247597515
# 	 pAcc:  0.303720931892404
#
#  Validation results:
# 	 - loss=0.5560200492540995
# ...

# %%
args_dict = {
    #arguments for the experimental setup
    'seed' : 42,
    'dataset' : 'idda',
    'model' : 'deeplabv3_mobilenetv2',
    'num_epochs' : 50,
    'n_exp' : 28,
    'print_times' : False,
    #arguments for the model parameters
    'da' : 'advanced',
    'bs' : 8,
    'nw' : 2,
    'lr': 0.1,
    'wd' : 0.0001,
    #arguments for the optimizer and scheduler
    'opt' : 'SGD',
    'm' : 0.9,
    'policy' : 'step',
    'lr_step' : 10,
    'lr_factor' : 0.5,
    #arguments for the handling of validation and testing
    'test' : False,
    'warmup' : 0,
    'train_display_interval' : 1,
    'valid_interval' : 1,
    'n_final_epochs' : 5,
    'save_best_model' : False
}

experiment_t1(args_dict)
# Out:
#
#
#  #############################################
#
#  I'm in the experiment:
#   Namespace(seed=42, dataset='idda', model='deeplabv3_mobilenetv2', num_epochs=50, n_exp=28, print_times=False, da='advanced', bs=8, nw=2, lr=0.1, wd=0.0001, hnm=None, opt='SGD', m=0.9, policy='step', lr_power=0.9, lr_step=10, lr_factor=0.5, Adam_p=None, test=False, warmup=0, train_display_interval=1, valid_interval=1, n_final_epochs=5, save_best_model=False)
#  Generating datasets...
#  ...done
#  Splitting the training set...
#  ...done
#
#
#  Epoch 1/50
#
#  Train results for current epoch:
# 	 loss:  0.6548561076323192
# 	 mIoU:  0.24246747128706816
# 	 fwIoU:  0.6822600717174171
# 	 pAcc:  0.2940028478172381
#
#  Validation results:
# 	 - loss=1.065899960199992
# 	 - mIoU=0.17388489924207307
# 	 - fwIoU=0.5412895498763011
# 	 - pAcc=0.23893386302656155
#
#
#  Epoch 2/50
#
#  Train results for current epoch:
# 	 loss:  0.42914493729670844
# 	 mIoU:  0.28177951878557583
# 	 fwIoU:  0.7645104311502258
# ...

# %%
args_dict = {
    #arguments for the experimental setup
    'seed' : 42,
    'dataset' : 'idda',
    'model' : 'deeplabv3_mobilenetv2',
    'num_epochs' : 100,
    'n_exp' : 29,
    'print_times' : False,
    #arguments for the model parameters
    'da' : 'advanced',
    'bs' : 8,
    'nw' : 2,
    'lr': 0.1,
    'wd' : 0.0001,
    #arguments for the optimizer and scheduler
    'opt' : 'SGD',
    'm' : 0.9,
    'policy' : 'poly',
    'lr_power' : 0.9,
    #arguments for the handling of validation and testing
    'test' : True,
    'warmup' : 0,
    'train_display_interval' : 1,
    'valid_interval' : 1,
    'n_final_epochs' : 5,
    'save_best_model' : True
}

experiment_t1(args_dict)
# Out:
#
#
#  #############################################
#
#  I'm in the experiment:
#   Namespace(seed=42, dataset='idda', model='deeplabv3_mobilenetv2', num_epochs=100, n_exp=29, print_times=False, da='advanced', bs=8, nw=2, lr=0.1, wd=0.0001, hnm=None, opt='SGD', m=0.9, policy='poly', lr_power=0.9, lr_step=15, lr_factor=0.1, Adam_p=None, test=True, warmup=0, train_display_interval=1, valid_interval=1, n_final_epochs=5, save_best_model=True)
# Downloading: "https://github.com/d-li14/mobilenetv2.pytorch/raw/master/pretrained/mobilenetv2_1.0-0c6065bc.pth" to /root/.cache/torch/hub/checkpoints/mobilenetv2_1.0-0c6065bc.pth
# 100%|██████████| 13.5M/13.5M [00:00<00:00, 125MB/s]
#  Generating datasets...
#  ...done
#  Splitting the training set...
#  ...done
#
#
#  Epoch 1/100
#
#  Train results for current epoch:
# 	 loss:  0.6312537744641304
# 	 mIoU:  0.2476147569618159
# 	 fwIoU:  0.6933670634507408
# 	 pAcc:  0.298635583734822
#
#  Validation results:
# 	 - loss=0.6188732385635376
# ...

# %%
args_dict = {
    #arguments for the experimental setup
    'seed' : 42,
    'dataset' : 'idda',
    'model' : 'deeplabv3_mobilenetv2',
    'num_epochs' : 200,
    'n_exp' : 30,
    'print_times' : False,
    #arguments for the model parameters
    'da' : 'advanced',
    'bs' : 8,
    'nw' : 2,
    'lr': 0.1,
    'wd' : 0.0001,
    #arguments for the optimizer and scheduler
    'opt' : 'SGD',
    'm' : 0.9,
    'policy' : 'poly',
    'lr_power' : 0.9,
    #arguments for the handling of validation and testing
    'test' : True,
    'warmup' : 0,
    'train_display_interval' : 1,
    'valid_interval' : 1,
    'n_final_epochs' : 5,
    'save_best_model' : True
}

experiment_t1(args_dict)
# Out:
#
#
#  #############################################
#
#  I'm in the experiment:
#   Namespace(seed=42, dataset='idda', model='deeplabv3_mobilenetv2', num_epochs=200, n_exp=30, print_times=False, da='advanced', bs=8, nw=2, lr=0.1, wd=0.0001, hnm=None, opt='SGD', m=0.9, policy='poly', lr_power=0.9, lr_step=15, lr_factor=0.1, Adam_p=None, test=True, warmup=0, train_display_interval=1, valid_interval=1, n_final_epochs=5, save_best_model=True)
# Downloading: "https://github.com/d-li14/mobilenetv2.pytorch/raw/master/pretrained/mobilenetv2_1.0-0c6065bc.pth" to /root/.cache/torch/hub/checkpoints/mobilenetv2_1.0-0c6065bc.pth
# 100%|██████████| 13.5M/13.5M [00:00<00:00, 129MB/s]
#  Generating datasets...
#  ...done
#  Splitting the training set...
#  ...done
#
#
#  Epoch 1/200
#
#  Train results for current epoch:
# 	 loss:  0.6366392791271209
# 	 mIoU:  0.24838383792877303
# 	 fwIoU:  0.6926329836162918
# 	 pAcc:  0.29969882730804964
#
#  Validation results:
# 	 - loss=0.47417727708816526
# ...
