# %%
#Mounting the drive
#import os
#import sys

from google.colab import drive
drive.mount('/content/drive')
# %cd "/content/drive/MyDrive/MLDL-Project/Code/Codebase_inUse"
#sys.path.append(os.path.abspath('Code/Codebase_inUse'))
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/MLDL-Project/Code/Codebase_inUse

# %%
from model_t5_ext2 import *

# %%
# !cp -r "/content/drive/MyDrive/MLDL-Project/Code/Codebase_inUse/data" "/content/"
# %cd "/content/"
# Out:
# /content

# %%
# Interpolation, p=0.5

args_dict = {
    'seed' : 42,
    'dataset' : 'gtaV',
    'model' : 'deeplabv3_mobilenetv2',
    'num_epochs' : 100,
    'n_exp' : 1,
    'print_times' : True,
    'da' : 'advanced',
    'bs' : 8,
    'nw' : 2,
    'lr': 0.01,
    'wd' : 0.00001,
    'hnm' : False,
    'opt' : 'SGD',
    'm' : 0.9,
    'policy' : 'poly',
    'lr_power' : 0.9,
    'test' : True,
    'warmup' : 0,
    'train_display_interval' : 1,
    'valid_interval' : 10,
    'n_final_epochs' : 5,
    'save_best_model' : False,
    'style_transfer' : True,
    'L' : 0.000001,
    'num_images_per_style' : 25,
    'n_cl':15,
    'm_cl': 2,
    'N_cl':15,
    'mode': 'interpolation',
    'p_interpolation':0.5
}


experiment_t5_ext2(args_dict)
# Out:
#
#
#  #############################################
#
#  I'm in the experiment:
#   Namespace(seed=42, dataset='gtaV', model='deeplabv3_mobilenetv2', num_epochs=100, n_exp=1, print_times=True, mode='interpolation', p_interpolation=0.5, da='advanced', bs=8, nw=2, lr=0.01, wd=1e-05, hnm=False, opt='SGD', m=0.9, policy='poly', lr_power=0.9, lr_step=15, lr_factor=0.1, Adam_p=None, test=True, warmup=0, train_display_interval=1, valid_interval=10, n_final_epochs=5, save_best_model=False, style_transfer=True, L=1e-06, num_images_per_style=25, n_cl=15, m_cl=2, N_cl=15)
#  Generating datasets...
#  ...done
#  Creating the styles
# ...
# 100%|██████████| 25/25 [00:03<00:00,  6.75it/s]
#  Finished!
#
# Starting Clustering
#
# Finished!
#
# Best k:  5
#
#
#  Epoch 1/100
#
#  Time for train loop: 232.75 seconds
#
#  Train results for current epoch:
# 	 loss:  1.0349630598099
# 	 mIoU:  0.18787215518661798
# 	 fwIoU:  0.5311660924829854
# 	 pAcc:  0.2401116797371905
#
#
#  Epoch 2/100
#
# ...

# %%
# Noise

args_dict = {
    'seed' : 42,
    'dataset' : 'gtaV',
    'model' : 'deeplabv3_mobilenetv2',
    'num_epochs' : 100,
    'n_exp' : 2,
    'print_times' : True,
    'da' : 'advanced',
    'bs' : 8,
    'nw' : 2,
    'lr': 0.01,
    'wd' : 0.00001,
    'hnm' : False,
    'opt' : 'SGD',
    'm' : 0.9,
    'policy' : 'poly',
    'lr_power' : 0.9,
    'test' : True,
    'warmup' : 0,
    'train_display_interval' : 1,
    'valid_interval' : 10,
    'n_final_epochs' : 5,
    'save_best_model' : False,
    'style_transfer' : True,
    'L' : 0.000001,
    'num_images_per_style' : 25,
    'n_cl':15,
    'm_cl': 2,
    'N_cl':15,
    'mode': 'noise',
    'p_interpolation':0.5
}


experiment_t5_ext2(args_dict)

# !cp -r "/content/Results/Plots/Plots_T5.2/"* "/content/drive/MyDrive/MLDL-Project/Code/Codebase_inUse/Results/Plots/Plots_T5.2/"
# Out:
#
#
#  #############################################
#
#  I'm in the experiment:
#   Namespace(seed=42, dataset='gtaV', model='deeplabv3_mobilenetv2', num_epochs=100, n_exp=2, print_times=True, mode='noise', p_interpolation=0.5, da='advanced', bs=8, nw=2, lr=0.01, wd=1e-05, hnm=False, opt='SGD', m=0.9, policy='poly', lr_power=0.9, lr_step=15, lr_factor=0.1, Adam_p=None, test=True, warmup=0, train_display_interval=1, valid_interval=10, n_final_epochs=5, save_best_model=False, style_transfer=True, L=1e-06, num_images_per_style=25, n_cl=15, m_cl=2, N_cl=15)
#  Generating datasets...
#  ...done
#  Creating the styles
# ...
# 100%|██████████| 25/25 [00:04<00:00,  5.35it/s]
#  Finished!
#
#
#  Epoch 1/100
#  Time for train loop: 217.93 seconds
#
#  Train results for current epoch:
# 	 loss:  1.00741513554127
# 	 mIoU:  0.19180858052604446
# 	 fwIoU:  0.5408699967636923
# 	 pAcc:  0.24457688041689074
#
#
#  Epoch 2/100
#
#  Time for train loop: 224.16 seconds
#
#  Train results for current epoch:
# ...

# %%
# Interpolation, p=0.3

args_dict = {
    'seed' : 42,
    'dataset' : 'gtaV',
    'model' : 'deeplabv3_mobilenetv2',
    'num_epochs' : 30,
    'n_exp' : 3,
    'print_times' : True,
    'da' : 'advanced',
    'bs' : 8,
    'nw' : 2,
    'lr': 0.01,
    'wd' : 0.00001,
    'hnm' : False,
    'opt' : 'SGD',
    'm' : 0.9,
    'policy' : 'poly',
    'lr_power' : 0.9,
    'test' : True,
    'warmup' : 0,
    'train_display_interval' : 1,
    'valid_interval' : 5,
    'n_final_epochs' : 3,
    'save_best_model' : False,
    'style_transfer' : True,
    'L' : 0.000001,
    'num_images_per_style' : 5,
    'n_cl':15,
    'm_cl': 2,
    'N_cl':15,
    'mode': 'interpolation',
    'p_interpolation':0.2
}

experiment_t5_ext2(args_dict)

# !cp -r "/content/Results/Plots/Plots_T5.2/"* "/content/drive/MyDrive/MLDL-Project/Code/Codebase_inUse/Results/Plots/Plots_T5.2/"
# Out:
#
#
#  #############################################
#
#  I'm in the experiment:
#   Namespace(seed=42, dataset='gtaV', model='deeplabv3_mobilenetv2', num_epochs=30, n_exp=3, print_times=True, mode='interpolation', p_interpolation=0.2, da='advanced', bs=8, nw=2, lr=0.01, wd=1e-05, hnm=False, opt='SGD', m=0.9, policy='poly', lr_power=0.9, lr_step=15, lr_factor=0.1, Adam_p=None, test=True, warmup=0, train_display_interval=1, valid_interval=5, n_final_epochs=3, save_best_model=False, style_transfer=True, L=1e-06, num_images_per_style=5, n_cl=15, m_cl=2, N_cl=15)
#  Generating datasets...
#  ...done
#  Creating the styles
# ...
# 100%|██████████| 5/5 [00:00<00:00,  6.95it/s]
#  Finished!
#
# Starting Clustering
#
# Finished!
#
# Best k:  2
#
#
#  Epoch 1/30
#
#  Time for train loop: 222.31 seconds
#
#  Train results for current epoch:
# 	 loss:  1.011645418982352
# 	 mIoU:  0.19141375409850783
# 	 fwIoU:  0.540855461315575
# 	 pAcc:  0.24413894460627483
#
#
#  Epoch 2/30
#
# ...

# %%
# noise

args_dict = {
    'seed' : 42,
    'dataset' : 'gtaV',
    'model' : 'deeplabv3_mobilenetv2',
    'num_epochs' : 30,
    'n_exp' : 3,
    'print_times' : True,
    'da' : 'advanced',
    'bs' : 8,
    'nw' : 2,
    'lr': 0.01,
    'wd' : 0.00001,
    'hnm' : False,
    'opt' : 'SGD',
    'm' : 0.9,
    'policy' : 'poly',
    'lr_power' : 0.9,
    'test' : True,
    'warmup' : 0,
    'train_display_interval' : 1,
    'valid_interval' : 5,
    'n_final_epochs' : 3,
    'save_best_model' : False,
    'style_transfer' : True,
    'L' : 0.000001,
    'num_images_per_style' : 5,
    'n_cl':15,
    'm_cl': 2,
    'N_cl':15,
    'mode': 'noise',
    'p_interpolation':0.2
}

experiment_t5_ext2(args_dict)

# !cp -r "/content/Results/Plots/Plots_T5.2/"* "/content/drive/MyDrive/MLDL-Project/Code/Codebase_inUse/Results/Plots/Plots_T5.2/"
# Out:
#
#
#  #############################################
#
#  I'm in the experiment:
#   Namespace(seed=42, dataset='gtaV', model='deeplabv3_mobilenetv2', num_epochs=30, n_exp=3, print_times=True, mode='noise', p_interpolation=0.2, da='advanced', bs=8, nw=2, lr=0.01, wd=1e-05, hnm=False, opt='SGD', m=0.9, policy='poly', lr_power=0.9, lr_step=15, lr_factor=0.1, Adam_p=None, test=True, warmup=0, train_display_interval=1, valid_interval=5, n_final_epochs=3, save_best_model=False, style_transfer=True, L=1e-06, num_images_per_style=5, n_cl=15, m_cl=2, N_cl=15)
# Downloading: "https://github.com/d-li14/mobilenetv2.pytorch/raw/master/pretrained/mobilenetv2_1.0-0c6065bc.pth" to /root/.cache/torch/hub/checkpoints/mobilenetv2_1.0-0c6065bc.pth
# 100%|██████████| 13.5M/13.5M [00:00<00:00, 242MB/s]
#  Generating datasets...
#  ...done
#  Creating the styles
# ...
# 100%|██████████| 5/5 [00:00<00:00,  7.15it/s]
#  Finished!
#
#
#  Epoch 1/30
#
#  Time for train loop: 234.62 seconds
#
# ...

# %%
# Interpolation, p=0.5

args_dict = {
    'seed' : 42,
    'dataset' : 'gtaV',
    'model' : 'deeplabv3_mobilenetv2',
    'num_epochs' : 30,
    'n_exp' : 3,
    'print_times' : True,
    'da' : 'advanced',
    'bs' : 8,
    'nw' : 2,
    'lr': 0.01,
    'wd' : 0.00001,
    'hnm' : False,
    'opt' : 'SGD',
    'm' : 0.9,
    'policy' : 'poly',
    'lr_power' : 0.9,
    'test' : True,
    'warmup' : 0,
    'train_display_interval' : 1,
    'valid_interval' : 5,
    'n_final_epochs' : 3,
    'save_best_model' : False,
    'style_transfer' : True,
    'L' : 0.000001,
    'num_images_per_style' : 5,
    'n_cl':15,
    'm_cl': 2,
    'N_cl':15,
    'mode': 'interpolation',
    'p_interpolation':0.5
}

experiment_t5_ext2(args_dict)

# !cp -r "/content/Results/Plots/Plots_T5.2/"* "/content/drive/MyDrive/MLDL-Project/Code/Codebase_inUse/Results/Plots/Plots_T5.2/"
# Out:
#
#
#  #############################################
#
#  I'm in the experiment:
#   Namespace(seed=42, dataset='gtaV', model='deeplabv3_mobilenetv2', num_epochs=30, n_exp=3, print_times=True, mode='interpolation', p_interpolation=0.5, da='advanced', bs=8, nw=2, lr=0.01, wd=1e-05, hnm=False, opt='SGD', m=0.9, policy='poly', lr_power=0.9, lr_step=15, lr_factor=0.1, Adam_p=None, test=True, warmup=0, train_display_interval=1, valid_interval=5, n_final_epochs=3, save_best_model=False, style_transfer=True, L=1e-06, num_images_per_style=5, n_cl=15, m_cl=2, N_cl=15)
#  Generating datasets...
#  ...done
#  Creating the styles
# ...
# 100%|██████████| 5/5 [00:00<00:00,  6.98it/s]
#  Finished!
#
# Starting Clustering
#
# Finished!
#
# Best k:  2
#
#
#  Epoch 1/30
#
#  Time for train loop: 223.81 seconds
#
#  Train results for current epoch:
# 	 loss:  1.0332979266681979
# 	 mIoU:  0.18899411167964375
# 	 fwIoU:  0.5332677119817435
# 	 pAcc:  0.2418394662186884
#
#
#  Epoch 2/30
#
# ...
